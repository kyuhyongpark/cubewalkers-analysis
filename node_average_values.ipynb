# %%
import cubewalkers as cw
import cupy as cp
from copy import deepcopy

# %%
IMPORT_RULES_FROM_FILES = True
cc_models_dir = './models/cell_collective/'
if IMPORT_RULES_FROM_FILES:
    from os import listdir
    
    sync_models = {}
    for fname in listdir(cc_models_dir):
        with open(cc_models_dir+fname) as rulefile:
            name = fname.strip('.txt')
            rules = rulefile.read()
            sync_models[name]=cw.Model(rules)
else:
    from cana.datasets.bio import load_all_cell_collective_models
    def cell_collective_models():
        return {BN.name:cw.Model(cw.conversions.network_rules_from_cana(BN)) 
                for BN in load_all_cell_collective_models()}
    sync_models = cell_collective_models()
    for name,model in sync_models.items():
        with open(cc_models_dir+name+'.txt','w') as rulefile:
            rulefile.write(model.rules)

total_models = len(sync_models)
async_models = deepcopy(sync_models)

# %%
def simulate_models(models, sync=True ,W=2500):
    convergence_measures = {}
    for model_idx, (model_name, model) in enumerate(models.items()):
        model.n_walkers = W
        N = model.n_variables
        timescale=2*N
        T = N**2 + 5 * timescale
        T_window = 5 * timescale
        model.n_time_steps = T

        print(f"Simulating Model {model_name} ({W=},{T=},{N=}). . .")
        if sync:
            model.simulate_ensemble(T_window=T_window,
                                    averages_only=True,
                                    maskfunction=cw.update_schemes.synchronous,
                                    threads_per_block=(16, 16))
        else:
            model.simulate_ensemble(T_window=T_window,
                                    averages_only=True,
                                    maskfunction=cw.update_schemes.asynchronous,
                                    threads_per_block=(16, 16))
            
        tw1 = model.trajectories[0*timescale:2*timescale]
        tw2 = model.trajectories[1*timescale:3*timescale]
        tw3 = model.trajectories[2*timescale:4*timescale]
        tw4 = model.trajectories[3*timescale:]
        convergence_measures[model_name] = max([
            cp.max(cp.abs(tw1.mean(axis=0) - tw2.mean(axis=0))),    
            cp.max(cp.abs(tw1.mean(axis=0) - tw3.mean(axis=0))),
            cp.max(cp.abs(tw1.mean(axis=0) - tw4.mean(axis=0))),
            cp.max(cp.abs(tw2.mean(axis=0) - tw3.mean(axis=0))),
            cp.max(cp.abs(tw2.mean(axis=0) - tw4.mean(axis=0))),
            cp.max(cp.abs(tw3.mean(axis=0) - tw4.mean(axis=0))),
            ])
        print(f"Progress: {(model_idx+1)}/{total_models},\t maximum difference: {convergence_measures[model_name]}")
    return convergence_measures

# %%
sync_convergence_measures=simulate_models(sync_models,sync=True)
# Out:
# Simulating Model T-LGL Survival Network 2011 Reduced Network (W=2500,T=504,N=18). . .
# Progress: 1/74,	 maximum difference: 0.0
# Simulating Model TOL Regulatory Network (W=2500,T=816,N=24). . .
# Progress: 2/74,	 maximum difference: 0.0
# Simulating Model B cell differentiation (W=2500,T=704,N=22). . .
# Progress: 3/74,	 maximum difference: 0.0
# Simulating Model Death Receptor Signaling (W=2500,T=1064,N=28). . .
# Progress: 4/74,	 maximum difference: 0.0005178571428572365
# Simulating Model HCC1954 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 5/74,	 maximum difference: 0.0
# Simulating Model IL-1 Signaling (W=2500,T=15104,N=118). . .
# Progress: 6/74,	 maximum difference: 0.0
# Simulating Model T-LGL Survival Network 2011 (W=2500,T=4200,N=60). . .
# Progress: 7/74,	 maximum difference: 0.0
# Simulating Model Mammalian Cell Cycle (W=2500,T=600,N=20). . .
# Progress: 8/74,	 maximum difference: 0.0
# Simulating Model Signaling in Macrophage Activation (W=2500,T=106251,N=321). . .
# Progress: 9/74,	 maximum difference: 1.8068535825588317e-05
# Simulating Model VEGF Pathway of Drosophila Signaling Pathway (W=2500,T=504,N=18). . .
# Progress: 10/74,	 maximum difference: 0.0
# Simulating Model BT474 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 11/74,	 maximum difference: 0.0
# Simulating Model HIV-1 interactions with T Cell Signalling Pathway (W=2500,T=20424,N=138). . .
# Progress: 12/74,	 maximum difference: 0.0
# Simulating Model Oxidative Stress Pathway (W=2500,T=551,N=19). . .
# Progress: 13/74,	 maximum difference: 0.00932105263157898
# Simulating Model Treatment of Castration-Resistant Prostate Cancer (W=2500,T=2184,N=42). . .
# Progress: 14/74,	 maximum difference: 0.0
# Simulating Model Cell Cycle Transcription by Coupled CDK and Network Oscillators (W=2500,T=171,N=9). . .
# Progress: 15/74,	 maximum difference: 0.0038888888888889
# Simulating Model Glucose Repression Signaling 2009 (W=2500,T=6059,N=73). . .
# Progress: 16/74,	 maximum difference: 9.589041095892092e-05
# Simulating Model Neurotransmitter Signaling Pathway (W=2500,T=416,N=16). . .
# Progress: 17/74,	 maximum difference: 0.0
# Simulating Model IL-6 Signalling (W=2500,T=8256,N=86). . .
# Progress: 18/74,	 maximum difference: 0.0003790697674418697
# Simulating Model Differentiation of T lymphocytes (W=2500,T=3000,N=50). . .
# Progress: 19/74,	 maximum difference: 0.0
# Simulating Model Budding Yeast Cell Cycle 2009 (W=2500,T=504,N=18). . .
# Progress: 20/74,	 maximum difference: 0.03770555555555544
# Simulating Model Signal Transduction in Fibroblasts (W=2500,T=20711,N=139). . .
# Progress: 21/74,	 maximum difference: 0.00010215827338133643
# Simulating Model BT474 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 22/74,	 maximum difference: 0.0
# Simulating Model Colitis-associated colon cancer (W=2500,T=5600,N=70). . .
# Progress: 23/74,	 maximum difference: 0.0004814285714286326
# Simulating Model T-LGL Survival Network 2008 (W=2500,T=4331,N=61). . .
# Progress: 24/74,	 maximum difference: 1.6393442622952142e-06
# Simulating Model Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (W=2500,T=936,N=26). . .
# Progress: 25/74,	 maximum difference: 0.0
# Simulating Model B bronchiseptica and T retortaeformis coinfection (W=2500,T=3339,N=53). . .
# Progress: 26/74,	 maximum difference: 0.0
# Simulating Model Lymphoid and myeloid cell specification and transdifferentiation (W=2500,T=1419,N=33). . .
# Progress: 27/74,	 maximum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 28/74,	 maximum difference: 0.0
# Simulating Model Cardiac developmen (W=2500,T=375,N=15). . .
# Progress: 29/74,	 maximum difference: 0.0
# Simulating Model Cortical Area Developmen (W=2500,T=75,N=5). . .
# Progress: 30/74,	 maximum difference: 0.0
# Simulating Model HCC1954 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 31/74,	 maximum difference: 0.0
# Simulating Model Bordetella bronchiseptica (W=2500,T=1419,N=33). . .
# Progress: 32/74,	 maximum difference: 0.0
# Simulating Model MAPK Cancer Cell Fate Network (W=2500,T=3339,N=53). . .
# Progress: 33/74,	 maximum difference: 0.0016245283018868073
# Simulating Model Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (W=2500,T=5016,N=66). . .
# Progress: 34/74,	 maximum difference: 0.00014848484848484222
# Simulating Model Guard Cell Abscisic Acid Signaling (W=2500,T=2376,N=44). . .
# Progress: 35/74,	 maximum difference: 0.000579545454545527
# Simulating Model Human Gonadal Sex Determination (W=2500,T=551,N=19). . .
# Progress: 36/74,	 maximum difference: 0.0
# Simulating Model T Cell Receptor Signaling (W=2500,T=11211,N=101). . .
# Progress: 37/74,	 maximum difference: 0.00017920792079209602
# Simulating Model Yeast Apoptosis (W=2500,T=6059,N=73). . .
# Progress: 38/74,	 maximum difference: 0.0013493150684932287
# Simulating Model Influenza A Virus Replication Cycle (W=2500,T=18471,N=131). . .
# Progress: 39/74,	 maximum difference: 0.0
# Simulating Model Iron acquisition and oxidative stress response in aspergillus fumigatus (W=2500,T=704,N=22). . .
# Progress: 40/74,	 maximum difference: 0.006404545454545496
# Simulating Model Senescence Associated Secretory Phenotype (W=2500,T=3111,N=51). . .
# Progress: 41/74,	 maximum difference: 0.00028235294117651133
# Simulating Model Arabidopsis thaliana Cell Cycle (W=2500,T=336,N=14). . .
# Progress: 42/74,	 maximum difference: 0.011878571428571405
# Simulating Model FA BRCA pathway (W=2500,T=1064,N=28). . .
# Progress: 43/74,	 maximum difference: 0.0
# Simulating Model EGFR & ErbB Signaling (W=2500,T=11856,N=104). . .
# Progress: 44/74,	 maximum difference: 0.0003961538461538794
# Simulating Model PC12 Cell Differentiation (W=2500,T=4464,N=62). . .
# Progress: 45/74,	 maximum difference: 0.0
# Simulating Model CD4+ T cell Differentiation (W=2500,T=1824,N=38). . .
# Progress: 46/74,	 maximum difference: 8.947368421052815e-05
# Simulating Model Septation Initiation Network (W=2500,T=1271,N=31). . .
# Progress: 47/74,	 maximum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 48/74,	 maximum difference: 0.0
# Simulating Model Apoptosis Network (W=2500,T=2091,N=41). . .
# Progress: 49/74,	 maximum difference: 0.0009439024390245354
# Simulating Model HH Pathway of Drosophila Signaling Pathways (W=2500,T=816,N=24). . .
# Progress: 50/74,	 maximum difference: 0.0
# Simulating Model Toll Pathway of Drosophila Signaling Pathway (W=2500,T=231,N=11). . .
# Progress: 51/74,	 maximum difference: 0.0
# Simulating Model IGVH mutations in chronic lymphocytic leukemia (W=2500,T=9191,N=91). . .
# Progress: 52/74,	 maximum difference: 0.0
# Simulating Model HGF Signaling in Keratinocytes (W=2500,T=5304,N=68). . .
# Progress: 53/74,	 maximum difference: 8.235294117647785e-05
# Simulating Model Metabolic Interactions in the Gut Microbiome (W=2500,T=264,N=12). . .
# Progress: 54/74,	 maximum difference: 0.0
# Simulating Model Predicting Variabilities in Cardiac Gene (W=2500,T=375,N=15). . .
# Progress: 55/74,	 maximum difference: 0.0
# Simulating Model Bortezomib Responses in U266 Human Myeloma Cells (W=2500,T=5159,N=67). . .
# Progress: 56/74,	 maximum difference: 0.0
# Simulating Model Lymphopoiesis Regulatory Network (W=2500,T=7371,N=81). . .
# Progress: 57/74,	 maximum difference: 0.0
# Simulating Model Lac Operon (W=2500,T=299,N=13). . .
# Progress: 58/74,	 maximum difference: 0.0
# Simulating Model Budding Yeast Cell Cycle (W=2500,T=600,N=20). . .
# Progress: 59/74,	 maximum difference: 0.0019600000000000173
# Simulating Model T-Cell Signaling 2006 (W=2500,T=2000,N=40). . .
# Progress: 60/74,	 maximum difference: 0.0004150000000000542
# Simulating Model Processing of Spz Network from the Drosophila Signaling Pathway (W=2500,T=816,N=24). . .
# Progress: 61/74,	 maximum difference: 0.0
# Simulating Model Regulation of the L-arabinose operon of Escherichia coli (W=2500,T=299,N=13). . .
# Progress: 62/74,	 maximum difference: 0.0
# Simulating Model Trichostrongylus retortaeformis (W=2500,T=936,N=26). . .
# Progress: 63/74,	 maximum difference: 0.0
# Simulating Model Stomatal Opening Model (W=2500,T=2891,N=49). . .
# Progress: 64/74,	 maximum difference: 0.0
# Simulating Model Aurora Kinase A in Neuroblastoma (W=2500,T=759,N=23). . .
# Progress: 65/74,	 maximum difference: 0.0013565217391304785
# Simulating Model Fanconi anemia and checkpoint recovery (W=2500,T=375,N=15). . .
# Progress: 66/74,	 maximum difference: 0.0
# Simulating Model T cell differentiation (W=2500,T=759,N=23). . .
# Progress: 67/74,	 maximum difference: 0.0
# Simulating Model Cholesterol Regulatory Pathway (W=2500,T=1496,N=34). . .
# Progress: 68/74,	 maximum difference: 0.0004352941176470615
# Simulating Model FGF pathway of Drosophila Signalling Pathways (W=2500,T=759,N=23). . .
# Progress: 69/74,	 maximum difference: 0.0
# Simulating Model Tumour Cell Invasion and Migration (W=2500,T=1344,N=32). . .
# Progress: 70/74,	 maximum difference: 0.0
# Simulating Model Mammalian Cell Cycle 2006 (W=2500,T=200,N=10). . .
# Progress: 71/74,	 maximum difference: 0.018059999999999965
# Simulating Model Wg Pathway of Drosophila Signalling Pathways (W=2500,T=936,N=26). . .
# Progress: 72/74,	 maximum difference: 0.0
# Simulating Model CD4+ T Cell Differentiation and Plasticity (W=2500,T=504,N=18). . .
# Progress: 73/74,	 maximum difference: 0.0
# Simulating Model CD4 T cell signaling (W=2500,T=37224,N=188). . .
# Progress: 74/74,	 maximum difference: 9.361702127674842e-05

# %%
async_convergence_measures=simulate_models(async_models,sync=False)
# Out:
# Simulating Model T-LGL Survival Network 2011 Reduced Network (W=2500,T=504,N=18). . .
# Progress: 1/74,	 maximum difference: 0.002472222222222216
# Simulating Model TOL Regulatory Network (W=2500,T=816,N=24). . .
# Progress: 2/74,	 maximum difference: 0.0
# Simulating Model B cell differentiation (W=2500,T=704,N=22). . .
# Progress: 3/74,	 maximum difference: 0.0
# Simulating Model Death Receptor Signaling (W=2500,T=1064,N=28). . .
# Progress: 4/74,	 maximum difference: 0.0
# Simulating Model HCC1954 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 5/74,	 maximum difference: 0.0
# Simulating Model IL-1 Signaling (W=2500,T=15104,N=118). . .
# Progress: 6/74,	 maximum difference: 0.0
# Simulating Model T-LGL Survival Network 2011 (W=2500,T=4200,N=60). . .
# Progress: 7/74,	 maximum difference: 0.0018450000000000012
# Simulating Model Mammalian Cell Cycle (W=2500,T=600,N=20). . .
# Progress: 8/74,	 maximum difference: 0.0
# Simulating Model Signaling in Macrophage Activation (W=2500,T=106251,N=321). . .
# Progress: 9/74,	 maximum difference: 0.01047258566978193
# Simulating Model VEGF Pathway of Drosophila Signaling Pathway (W=2500,T=504,N=18). . .
# Progress: 10/74,	 maximum difference: 0.0
# Simulating Model BT474 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 11/74,	 maximum difference: 0.0
# Simulating Model HIV-1 interactions with T Cell Signalling Pathway (W=2500,T=20424,N=138). . .
# Progress: 12/74,	 maximum difference: 0.0
# Simulating Model Oxidative Stress Pathway (W=2500,T=551,N=19). . .
# Progress: 13/74,	 maximum difference: 0.01187368421052637
# Simulating Model Treatment of Castration-Resistant Prostate Cancer (W=2500,T=2184,N=42). . .
# Progress: 14/74,	 maximum difference: 0.0
# Simulating Model Cell Cycle Transcription by Coupled CDK and Network Oscillators (W=2500,T=171,N=9). . .
# Progress: 15/74,	 maximum difference: 0.0047888888888888885
# Simulating Model Glucose Repression Signaling 2009 (W=2500,T=6059,N=73). . .
# Progress: 16/74,	 maximum difference: 0.0
# Simulating Model Neurotransmitter Signaling Pathway (W=2500,T=416,N=16). . .
# Progress: 17/74,	 maximum difference: 0.012443750000000031
# Simulating Model IL-6 Signalling (W=2500,T=8256,N=86). . .
# Progress: 18/74,	 maximum difference: 0.007095348837209303
# Simulating Model Differentiation of T lymphocytes (W=2500,T=3000,N=50). . .
# Progress: 19/74,	 maximum difference: 0.0
# Simulating Model Budding Yeast Cell Cycle 2009 (W=2500,T=504,N=18). . .
# Progress: 20/74,	 maximum difference: 0.016488888888888886
# Simulating Model Signal Transduction in Fibroblasts (W=2500,T=20711,N=139). . .
# Progress: 21/74,	 maximum difference: 0.02118992805755404
# Simulating Model BT474 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 22/74,	 maximum difference: 0.0
# Simulating Model Colitis-associated colon cancer (W=2500,T=5600,N=70). . .
# Progress: 23/74,	 maximum difference: 0.011082857142857172
# Simulating Model T-LGL Survival Network 2008 (W=2500,T=4331,N=61). . .
# Progress: 24/74,	 maximum difference: 0.0017442622950819657
# Simulating Model Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (W=2500,T=936,N=26). . .
# Progress: 25/74,	 maximum difference: 0.008811538461538482
# Simulating Model B bronchiseptica and T retortaeformis coinfection (W=2500,T=3339,N=53). . .
# Progress: 26/74,	 maximum difference: 0.0
# Simulating Model Lymphoid and myeloid cell specification and transdifferentiation (W=2500,T=1419,N=33). . .
# Progress: 27/74,	 maximum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Short-term ErbB Network (W=2500,T=416,N=16). . .
# Progress: 28/74,	 maximum difference: 0.0
# Simulating Model Cardiac developmen (W=2500,T=375,N=15). . .
# Progress: 29/74,	 maximum difference: 0.00047333333333343663
# Simulating Model Cortical Area Developmen (W=2500,T=75,N=5). . .
# Progress: 30/74,	 maximum difference: 0.01432000000000011
# Simulating Model HCC1954 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 31/74,	 maximum difference: 0.0
# Simulating Model Bordetella bronchiseptica (W=2500,T=1419,N=33). . .
# Progress: 32/74,	 maximum difference: 0.0048393939393939385
# Simulating Model MAPK Cancer Cell Fate Network (W=2500,T=3339,N=53). . .
# Progress: 33/74,	 maximum difference: 0.01056415094339623
# Simulating Model Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (W=2500,T=5016,N=66). . .
# Progress: 34/74,	 maximum difference: 0.010424242424242405
# Simulating Model Guard Cell Abscisic Acid Signaling (W=2500,T=2376,N=44). . .
# Progress: 35/74,	 maximum difference: 0.01137045454545449
# Simulating Model Human Gonadal Sex Determination (W=2500,T=551,N=19). . .
# Progress: 36/74,	 maximum difference: 0.0
# Simulating Model T Cell Receptor Signaling (W=2500,T=11211,N=101). . .
# Progress: 37/74,	 maximum difference: 0.007288118811881239
# Simulating Model Yeast Apoptosis (W=2500,T=6059,N=73). . .
# Progress: 38/74,	 maximum difference: 0.006876712328767187
# Simulating Model Influenza A Virus Replication Cycle (W=2500,T=18471,N=131). . .
# Progress: 39/74,	 maximum difference: 0.0005687022900763357
# Simulating Model Iron acquisition and oxidative stress response in aspergillus fumigatus (W=2500,T=704,N=22). . .
# Progress: 40/74,	 maximum difference: 0.018304545454545462
# Simulating Model Senescence Associated Secretory Phenotype (W=2500,T=3111,N=51). . .
# Progress: 41/74,	 maximum difference: 0.0066882352941175505
# Simulating Model Arabidopsis thaliana Cell Cycle (W=2500,T=336,N=14). . .
# Progress: 42/74,	 maximum difference: 0.01552142857142863
# Simulating Model FA BRCA pathway (W=2500,T=1064,N=28). . .
# Progress: 43/74,	 maximum difference: 0.022574999999999994
# Simulating Model EGFR & ErbB Signaling (W=2500,T=11856,N=104). . .
# Progress: 44/74,	 maximum difference: 0.009059615384615416
# Simulating Model PC12 Cell Differentiation (W=2500,T=4464,N=62). . .
# Progress: 45/74,	 maximum difference: 0.0
# Simulating Model CD4+ T cell Differentiation (W=2500,T=1824,N=38). . .
# Progress: 46/74,	 maximum difference: 0.002444736842105305
# Simulating Model Septation Initiation Network (W=2500,T=1271,N=31). . .
# Progress: 47/74,	 maximum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Long-term ErbB Network (W=2500,T=875,N=25). . .
# Progress: 48/74,	 maximum difference: 0.0
# Simulating Model Apoptosis Network (W=2500,T=2091,N=41). . .
# Progress: 49/74,	 maximum difference: 0.014929268292682929
# Simulating Model HH Pathway of Drosophila Signaling Pathways (W=2500,T=816,N=24). . .
# Progress: 50/74,	 maximum difference: 0.0
# Simulating Model Toll Pathway of Drosophila Signaling Pathway (W=2500,T=231,N=11). . .
# Progress: 51/74,	 maximum difference: 0.005199999999999982
# Simulating Model IGVH mutations in chronic lymphocytic leukemia (W=2500,T=9191,N=91). . .
# Progress: 52/74,	 maximum difference: 0.010125274725274719
# Simulating Model HGF Signaling in Keratinocytes (W=2500,T=5304,N=68). . .
# Progress: 53/74,	 maximum difference: 0.0010397058823526928
# Simulating Model Metabolic Interactions in the Gut Microbiome (W=2500,T=264,N=12). . .
# Progress: 54/74,	 maximum difference: 0.0
# Simulating Model Predicting Variabilities in Cardiac Gene (W=2500,T=375,N=15). . .
# Progress: 55/74,	 maximum difference: 0.00027333333333334764
# Simulating Model Bortezomib Responses in U266 Human Myeloma Cells (W=2500,T=5159,N=67). . .
# Progress: 56/74,	 maximum difference: 0.0
# Simulating Model Lymphopoiesis Regulatory Network (W=2500,T=7371,N=81). . .
# Progress: 57/74,	 maximum difference: 0.0
# Simulating Model Lac Operon (W=2500,T=299,N=13). . .
# Progress: 58/74,	 maximum difference: 0.0031076923076923113
# Simulating Model Budding Yeast Cell Cycle (W=2500,T=600,N=20). . .
# Progress: 59/74,	 maximum difference: 0.00540999999999997
# Simulating Model T-Cell Signaling 2006 (W=2500,T=2000,N=40). . .
# Progress: 60/74,	 maximum difference: 0.007992499999999958
# Simulating Model Processing of Spz Network from the Drosophila Signaling Pathway (W=2500,T=816,N=24). . .
# Progress: 61/74,	 maximum difference: 0.0
# Simulating Model Regulation of the L-arabinose operon of Escherichia coli (W=2500,T=299,N=13). . .
# Progress: 62/74,	 maximum difference: 0.00020769230769232538
# Simulating Model Trichostrongylus retortaeformis (W=2500,T=936,N=26). . .
# Progress: 63/74,	 maximum difference: 0.008076923076923072
# Simulating Model Stomatal Opening Model (W=2500,T=2891,N=49). . .
# Progress: 64/74,	 maximum difference: 0.002861224489796088
# Simulating Model Aurora Kinase A in Neuroblastoma (W=2500,T=759,N=23). . .
# Progress: 65/74,	 maximum difference: 0.01087391304347829
# Simulating Model Fanconi anemia and checkpoint recovery (W=2500,T=375,N=15). . .
# Progress: 66/74,	 maximum difference: 0.02282
# Simulating Model T cell differentiation (W=2500,T=759,N=23). . .
# Progress: 67/74,	 maximum difference: 0.00025652173913037757
# Simulating Model Cholesterol Regulatory Pathway (W=2500,T=1496,N=34). . .
# Progress: 68/74,	 maximum difference: 0.005744117647058844
# Simulating Model FGF pathway of Drosophila Signalling Pathways (W=2500,T=759,N=23). . .
# Progress: 69/74,	 maximum difference: 0.0
# Simulating Model Tumour Cell Invasion and Migration (W=2500,T=1344,N=32). . .
# Progress: 70/74,	 maximum difference: 0.00040000000000006697
# Simulating Model Mammalian Cell Cycle 2006 (W=2500,T=200,N=10). . .
# Progress: 71/74,	 maximum difference: 0.04071000000000008
# Simulating Model Wg Pathway of Drosophila Signalling Pathways (W=2500,T=936,N=26). . .
# Progress: 72/74,	 maximum difference: 0.007046153846153827
# Simulating Model CD4+ T Cell Differentiation and Plasticity (W=2500,T=504,N=18). . .
# Progress: 73/74,	 maximum difference: 0.0
# Simulating Model CD4 T cell signaling (W=2500,T=37224,N=188). . .
# Progress: 74/74,	 maximum difference: 0.0

# %%
print(f'{max(sync_convergence_measures.values())}')
print(f'{max(async_convergence_measures.values())}')
# Out:
# 0.03770555555555544
# 0.04071000000000008

# %%
with open('./data/converged_average_node_values.csv','w') as f:
    for model_name, smodel, amodel in [(k,sync_models[k],async_models[k]) for k in sorted(async_models)]:
        straj = ','.join(map(lambda x: str(cp.round(x,3)),cp.mean(smodel.trajectories,axis=0)))
        atraj = ','.join(map(lambda x: str(cp.round(x,3)),cp.mean(amodel.trajectories,axis=0)))
        f.write(f'{model_name},{cp.round(sync_convergence_measures[model_name],3)},synchronous,{straj}\n')
        f.write(f'{model_name},{cp.round(async_convergence_measures[model_name],3)},asynchronous,{atraj}\n')
