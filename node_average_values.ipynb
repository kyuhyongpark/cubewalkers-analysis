# %%
import cubewalkers as cw
import cupy as cp
from copy import deepcopy

# %%
IMPORT_RULES_FROM_FILES = True
cc_models_dir = './models/cell_collective/'
if IMPORT_RULES_FROM_FILES:
    from os import listdir
    
    sync_models = {}
    for fname in listdir(cc_models_dir):
        with open(cc_models_dir+fname) as rulefile:
            name = fname.strip('.txt')
            rules = rulefile.read()
            sync_models[name]=cw.Model(rules)
else:
    from cana.datasets.bio import load_all_cell_collective_models
    def cell_collective_models():
        return {BN.name:cw.Model(cw.conversions.network_rules_from_cana(BN)) 
                for BN in load_all_cell_collective_models()}
    sync_models = cell_collective_models()
    for name,model in sync_models.items():
        with open(cc_models_dir+name+'.txt','w') as rulefile:
            rulefile.write(model.rules)

total_models = len(sync_models)
async_models = deepcopy(sync_models)

# %%
difficult_models = {
    'Arabidopsis thaliana Cell Cycle': (1000,1000),
    'Guard Cell Abscisic Acid Signaling': (5000, 5000),
    'Signal Transduction in Fibroblasts': (20000, 50000),
}

def simulate_models(models, sync=True ,W=2500):
    convergence_measures = {}
    convergence_measures_alt = {}
    for model_idx, (model_name, model) in enumerate(sorted(models.items())):
        model.n_walkers = W
        N = model.n_variables
        
        if model_name in difficult_models:
            timescale, T_burn = difficult_models[model_name]
        else:
            timescale = N + 1000
            T_burn = N*50 + 1000
        
        T_window = 5 * timescale        
        T = T_burn + T_window            
        
        model.n_time_steps = T

        print(f"Simulating Model {model_name} ({W=},{T=},{T_burn=},{T_window=},{N=}). . .")
        if sync:
            model.simulate_ensemble(T_window=T_window,
                                    averages_only=True,
                                    maskfunction=cw.update_schemes.synchronous,
                                    threads_per_block=(16, 16))
        else:
            model.simulate_ensemble(T_window=T_window,
                                    averages_only=True,
                                    maskfunction=cw.update_schemes.asynchronous,
                                    threads_per_block=(16, 16))
            
        tw1 = model.trajectories[0*timescale:2*timescale]
        tw2 = model.trajectories[1*timescale:3*timescale]
        tw3 = model.trajectories[2*timescale:4*timescale]
        tw4 = model.trajectories[3*timescale:]
        convergence_measures[model_name] = max([
            cp.max(cp.abs(tw1.mean(axis=0) - tw2.mean(axis=0))),    
            cp.max(cp.abs(tw1.mean(axis=0) - tw3.mean(axis=0))),
            cp.max(cp.abs(tw1.mean(axis=0) - tw4.mean(axis=0))),
            cp.max(cp.abs(tw2.mean(axis=0) - tw3.mean(axis=0))),
            cp.max(cp.abs(tw2.mean(axis=0) - tw4.mean(axis=0))),
            cp.max(cp.abs(tw3.mean(axis=0) - tw4.mean(axis=0))),
            ])
        convergence_measures_alt[model_name] = max([
            cp.sum(cp.abs(tw1.mean(axis=0) - tw2.mean(axis=0))),    
            cp.sum(cp.abs(tw1.mean(axis=0) - tw3.mean(axis=0))),
            cp.sum(cp.abs(tw1.mean(axis=0) - tw4.mean(axis=0))),
            cp.sum(cp.abs(tw2.mean(axis=0) - tw3.mean(axis=0))),
            cp.sum(cp.abs(tw2.mean(axis=0) - tw4.mean(axis=0))),
            cp.sum(cp.abs(tw3.mean(axis=0) - tw4.mean(axis=0))),
            ])
        
        print(f"Progress: {(model_idx+1)}/{total_models},\t maximum difference: {convergence_measures[model_name]},\t sum difference: {convergence_measures_alt[model_name]}")
    return convergence_measures,convergence_measures_alt

# %%
sync_convergence_measures,sync_alt=simulate_models(sync_models,sync=True)
# Out:
# Simulating Model Apoptosis Network (W=2500,T=8255,T_burn=3050,T_window=5205,N=41). . .
# Progress: 1/74,	 maximum difference: 8.030739673389742e-05,	 sum difference: 0.0005727185398656468
# Simulating Model Arabidopsis thaliana Cell Cycle (W=2500,T=6000,T_burn=1000,T_window=5000,N=14). . .
# Progress: 2/74,	 maximum difference: 0.0004964000000000635,	 sum difference: 0.004335200000000039
# Simulating Model Aurora Kinase A in Neuroblastoma (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 3/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model B bronchiseptica and T retortaeformis coinfection (W=2500,T=8915,T_burn=3650,T_window=5265,N=53). . .
# Progress: 4/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model B cell differentiation (W=2500,T=7210,T_burn=2100,T_window=5110,N=22). . .
# Progress: 5/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model BT474 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 6/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model BT474 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 7/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Bordetella bronchiseptica (W=2500,T=7815,T_burn=2650,T_window=5165,N=33). . .
# Progress: 8/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Bortezomib Responses in U266 Human Myeloma Cells (W=2500,T=9685,T_burn=4350,T_window=5335,N=67). . .
# Progress: 9/74,	 maximum difference: 1.87441424603918e-07,	 sum difference: 2.4367385189885595e-06
# Simulating Model Budding Yeast Cell Cycle (W=2500,T=7100,T_burn=2000,T_window=5100,N=20). . .
# Progress: 10/74,	 maximum difference: 6.568627450980608e-05,	 sum difference: 0.0005919607843136564
# Simulating Model Budding Yeast Cell Cycle 2009 (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 11/74,	 maximum difference: 0.00039705304518655726,	 sum difference: 0.003898624754420807
# Simulating Model CD4 T cell signaling (W=2500,T=16340,T_burn=10400,T_window=5940,N=188). . .
# Progress: 12/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model CD4+ T Cell Differentiation and Plasticity (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 13/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model CD4+ T cell Differentiation (W=2500,T=8090,T_burn=2900,T_window=5190,N=38). . .
# Progress: 14/74,	 maximum difference: 5.587668593459716e-06,	 sum difference: 2.7360308285179213e-05
# Simulating Model Cardiac developmen (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 15/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Cell Cycle Transcription by Coupled CDK and Network Oscillators (W=2500,T=6495,T_burn=1450,T_window=5045,N=9). . .
# Progress: 16/74,	 maximum difference: 0.00010842418235876283,	 sum difference: 0.00052011892963328
# Simulating Model Cholesterol Regulatory Pathway (W=2500,T=7870,T_burn=2700,T_window=5170,N=34). . .
# Progress: 17/74,	 maximum difference: 2.7852998065736045e-05,	 sum difference: 0.0003114119922631633
# Simulating Model Colitis-associated colon cancer (W=2500,T=9850,T_burn=4500,T_window=5350,N=70). . .
# Progress: 18/74,	 maximum difference: 6.598130841117822e-05,	 sum difference: 0.00017532710280379008
# Simulating Model Cortical Area Developmen (W=2500,T=6275,T_burn=1250,T_window=5025,N=5). . .
# Progress: 19/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Death Receptor Signaling (W=2500,T=7540,T_burn=2400,T_window=5140,N=28). . .
# Progress: 20/74,	 maximum difference: 2.548638132299219e-05,	 sum difference: 8.560311284008804e-05
# Simulating Model Differentiation of T lymphocytes (W=2500,T=8750,T_burn=3500,T_window=5250,N=50). . .
# Progress: 21/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model EGFR & ErbB Signaling (W=2500,T=11720,T_burn=6200,T_window=5520,N=104). . .
# Progress: 22/74,	 maximum difference: 4.275362318839626e-05,	 sum difference: 0.0006300724637682154
# Simulating Model FA BRCA pathway (W=2500,T=7540,T_burn=2400,T_window=5140,N=28). . .
# Progress: 23/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model FGF pathway of Drosophila Signalling Pathways (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 24/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Fanconi anemia and checkpoint recovery (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 25/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Glucose Repression Signaling 2009 (W=2500,T=10015,T_burn=4650,T_window=5365,N=73). . .
# Progress: 26/74,	 maximum difference: 4.678471575031429e-05,	 sum difference: 0.0002946877912393675
# Simulating Model Guard Cell Abscisic Acid Signaling (W=2500,T=30000,T_burn=5000,T_window=25000,N=44). . .
# Progress: 27/74,	 maximum difference: 9.80000000000425e-06,	 sum difference: 8.008000000020443e-05
# Simulating Model HCC1954 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 28/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HCC1954 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 29/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HGF Signaling in Keratinocytes (W=2500,T=9740,T_burn=4400,T_window=5340,N=68). . .
# Progress: 30/74,	 maximum difference: 1.891385767788245e-05,	 sum difference: 0.0005022471910111808
# Simulating Model HH Pathway of Drosophila Signaling Pathways (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 31/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HIV-1 interactions with T Cell Signalling Pathway (W=2500,T=13590,T_burn=7900,T_window=5690,N=138). . .
# Progress: 32/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Human Gonadal Sex Determination (W=2500,T=7045,T_burn=1950,T_window=5095,N=19). . .
# Progress: 33/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model IGVH mutations in chronic lymphocytic leukemia (W=2500,T=11005,T_burn=5550,T_window=5455,N=91). . .
# Progress: 34/74,	 maximum difference: 5.279560036665354e-05,	 sum difference: 0.0001217231897342047
# Simulating Model IL-1 Signaling (W=2500,T=12490,T_burn=6900,T_window=5590,N=118). . .
# Progress: 35/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model IL-6 Signalling (W=2500,T=10730,T_burn=5300,T_window=5430,N=86). . .
# Progress: 36/74,	 maximum difference: 5.101289134439024e-05,	 sum difference: 0.0010441988950276007
# Simulating Model Influenza A Virus Replication Cycle (W=2500,T=13205,T_burn=7550,T_window=5655,N=131). . .
# Progress: 37/74,	 maximum difference: 3.5366931918655634e-07,	 sum difference: 2.8293545534931012e-06
# Simulating Model Iron acquisition and oxidative stress response in aspergillus fumigatus (W=2500,T=7210,T_burn=2100,T_window=5110,N=22). . .
# Progress: 38/74,	 maximum difference: 0.00016457925636004234,	 sum difference: 0.0018935420743641518
# Simulating Model Lac Operon (W=2500,T=6715,T_burn=1650,T_window=5065,N=13). . .
# Progress: 39/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Lymphoid and myeloid cell specification and transdifferentiation (W=2500,T=7815,T_burn=2650,T_window=5165,N=33). . .
# Progress: 40/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Lymphopoiesis Regulatory Network (W=2500,T=10455,T_burn=5050,T_window=5405,N=81). . .
# Progress: 41/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model MAPK Cancer Cell Fate Network (W=2500,T=8915,T_burn=3650,T_window=5265,N=53). . .
# Progress: 42/74,	 maximum difference: 8.622981956316056e-05,	 sum difference: 0.0011990503323844048
# Simulating Model Mammalian Cell Cycle (W=2500,T=7100,T_burn=2000,T_window=5100,N=20). . .
# Progress: 43/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Mammalian Cell Cycle 2006 (W=2500,T=6550,T_burn=1500,T_window=5050,N=10). . .
# Progress: 44/74,	 maximum difference: 0.00041405940594060886,	 sum difference: 0.002335247524752504
# Simulating Model Metabolic Interactions in the Gut Microbiome (W=2500,T=6660,T_burn=1600,T_window=5060,N=12). . .
# Progress: 45/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Neurotransmitter Signaling Pathway (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 46/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Oxidative Stress Pathway (W=2500,T=7045,T_burn=1950,T_window=5095,N=19). . .
# Progress: 47/74,	 maximum difference: 0.000264376840039271,	 sum difference: 0.0022942100098134327
# Simulating Model PC12 Cell Differentiation (W=2500,T=9410,T_burn=4100,T_window=5310,N=62). . .
# Progress: 48/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Predicting Variabilities in Cardiac Gene (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 49/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 50/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Processing of Spz Network from the Drosophila Signaling Pathway (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 51/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Regulation of the L-arabinose operon of Escherichia coli (W=2500,T=6715,T_burn=1650,T_window=5065,N=13). . .
# Progress: 52/74,	 maximum difference: 1.559723593289042e-05,	 sum difference: 7.245804540961798e-05
# Simulating Model SKBR3 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 53/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 54/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Senescence Associated Secretory Phenotype (W=2500,T=8805,T_burn=3550,T_window=5255,N=51). . .
# Progress: 55/74,	 maximum difference: 5.93720266412745e-05,	 sum difference: 0.00036898192197984403
# Simulating Model Septation Initiation Network (W=2500,T=7705,T_burn=2550,T_window=5155,N=31). . .
# Progress: 56/74,	 maximum difference: 0.00012085354025215267,	 sum difference: 0.00045043646944736837
# Simulating Model Signal Transduction in Fibroblasts (W=2500,T=150000,T_burn=50000,T_window=100000,N=139). . .
# Progress: 57/74,	 maximum difference: 9.60000000105321e-07,	 sum difference: 2.58100000010684e-05
# Simulating Model Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (W=2500,T=9630,T_burn=4300,T_window=5330,N=66). . .
# Progress: 58/74,	 maximum difference: 8.855534709184543e-05,	 sum difference: 0.001347842401501105
# Simulating Model Signaling in Macrophage Activation (W=2500,T=23655,T_burn=17050,T_window=6605,N=321). . .
# Progress: 59/74,	 maximum difference: 7.721423164275265e-05,	 sum difference: 0.0010484481453456318
# Simulating Model Stomatal Opening Model (W=2500,T=8695,T_burn=3450,T_window=5245,N=49). . .
# Progress: 60/74,	 maximum difference: 5.185891325054648e-05,	 sum difference: 8.922783603415585e-05
# Simulating Model T Cell Receptor Signaling (W=2500,T=11555,T_burn=6050,T_window=5505,N=101). . .
# Progress: 61/74,	 maximum difference: 3.669391462307603e-05,	 sum difference: 0.0004675749318798182
# Simulating Model T cell differentiation (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 62/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model T-Cell Signaling 2006 (W=2500,T=8200,T_burn=3000,T_window=5200,N=40). . .
# Progress: 63/74,	 maximum difference: 2.7884615384617117e-05,	 sum difference: 0.0003446153846153044
# Simulating Model T-LGL Survival Network 2008 (W=2500,T=9355,T_burn=4050,T_window=5305,N=61). . .
# Progress: 64/74,	 maximum difference: 7.540056550424607e-07,	 sum difference: 2.073515551367038e-06
# Simulating Model T-LGL Survival Network 2011 (W=2500,T=9300,T_burn=4000,T_window=5300,N=60). . .
# Progress: 65/74,	 maximum difference: 1.8867924528301783e-07,	 sum difference: 1.3207547169809893e-06
# Simulating Model T-LGL Survival Network 2011 Reduced Network (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 66/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model TOL Regulatory Network (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 67/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Toll Pathway of Drosophila Signaling Pathway (W=2500,T=6605,T_burn=1550,T_window=5055,N=11). . .
# Progress: 68/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Treatment of Castration-Resistant Prostate Cancer (W=2500,T=8310,T_burn=3100,T_window=5210,N=42). . .
# Progress: 69/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Trichostrongylus retortaeformis (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 70/74,	 maximum difference: 4.191033138401662e-05,	 sum difference: 0.0001676413255360873
# Simulating Model Tumour Cell Invasion and Migration (W=2500,T=7760,T_burn=2600,T_window=5160,N=32). . .
# Progress: 71/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model VEGF Pathway of Drosophila Signaling Pathway (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 72/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Wg Pathway of Drosophila Signalling Pathways (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 73/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Yeast Apoptosis (W=2500,T=10015,T_burn=4650,T_window=5365,N=73). . .
# Progress: 74/74,	 maximum difference: 0.00024119291705493318,	 sum difference: 0.00048238583410986635

# %%
async_convergence_measures,async_alt=simulate_models(async_models,sync=False)
# Out:
# Simulating Model Apoptosis Network (W=2500,T=8255,T_burn=3050,T_window=5205,N=41). . .
# Progress: 1/74,	 maximum difference: 0.00513448607108552,	 sum difference: 0.02854197886647515
# Simulating Model Arabidopsis thaliana Cell Cycle (W=2500,T=6000,T_burn=1000,T_window=5000,N=14). . .
# Progress: 2/74,	 maximum difference: 0.0034031999999999396,	 sum difference: 0.014820800000000245
# Simulating Model Aurora Kinase A in Neuroblastoma (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 3/74,	 maximum difference: 0.002465102639296113,	 sum difference: 0.009653176930596086
# Simulating Model B bronchiseptica and T retortaeformis coinfection (W=2500,T=8915,T_burn=3650,T_window=5265,N=53). . .
# Progress: 4/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model B cell differentiation (W=2500,T=7210,T_burn=2100,T_window=5110,N=22). . .
# Progress: 5/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model BT474 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 6/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model BT474 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 7/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Bordetella bronchiseptica (W=2500,T=7815,T_burn=2650,T_window=5165,N=33). . .
# Progress: 8/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Bortezomib Responses in U266 Human Myeloma Cells (W=2500,T=9685,T_burn=4350,T_window=5335,N=67). . .
# Progress: 9/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Budding Yeast Cell Cycle (W=2500,T=7100,T_burn=2000,T_window=5100,N=20). . .
# Progress: 10/74,	 maximum difference: 0.0005817647058827813,	 sum difference: 0.004297843137255487
# Simulating Model Budding Yeast Cell Cycle 2009 (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 11/74,	 maximum difference: 0.002913752455795615,	 sum difference: 0.023986640471512805
# Simulating Model CD4 T cell signaling (W=2500,T=16340,T_burn=10400,T_window=5940,N=188). . .
# Progress: 12/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model CD4+ T Cell Differentiation and Plasticity (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 13/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model CD4+ T cell Differentiation (W=2500,T=8090,T_burn=2900,T_window=5190,N=38). . .
# Progress: 14/74,	 maximum difference: 0.0010287090558767364,	 sum difference: 0.00436319845857519
# Simulating Model Cardiac developmen (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 15/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Cell Cycle Transcription by Coupled CDK and Network Oscillators (W=2500,T=6495,T_burn=1450,T_window=5045,N=9). . .
# Progress: 16/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Cholesterol Regulatory Pathway (W=2500,T=7870,T_burn=2700,T_window=5170,N=34). . .
# Progress: 17/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Colitis-associated colon cancer (W=2500,T=9850,T_burn=4500,T_window=5350,N=70). . .
# Progress: 18/74,	 maximum difference: 0.0038276635514017943,	 sum difference: 0.04402635514018595
# Simulating Model Cortical Area Developmen (W=2500,T=6275,T_burn=1250,T_window=5025,N=5). . .
# Progress: 19/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Death Receptor Signaling (W=2500,T=7540,T_burn=2400,T_window=5140,N=28). . .
# Progress: 20/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Differentiation of T lymphocytes (W=2500,T=8750,T_burn=3500,T_window=5250,N=50). . .
# Progress: 21/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model EGFR & ErbB Signaling (W=2500,T=11720,T_burn=6200,T_window=5520,N=104). . .
# Progress: 22/74,	 maximum difference: 0.006948369565216939,	 sum difference: 0.056785326086955884
# Simulating Model FA BRCA pathway (W=2500,T=7540,T_burn=2400,T_window=5140,N=28). . .
# Progress: 23/74,	 maximum difference: 0.001098249027237319,	 sum difference: 0.001098249027237319
# Simulating Model FGF pathway of Drosophila Signalling Pathways (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 24/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Fanconi anemia and checkpoint recovery (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 25/74,	 maximum difference: 0.001826009852216648,	 sum difference: 0.001826009852216648
# Simulating Model Glucose Repression Signaling 2009 (W=2500,T=10015,T_burn=4650,T_window=5365,N=73). . .
# Progress: 26/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Guard Cell Abscisic Acid Signaling (W=2500,T=30000,T_burn=5000,T_window=25000,N=44). . .
# Progress: 27/74,	 maximum difference: 0.0019425199999998921,	 sum difference: 0.007317639999999959
# Simulating Model HCC1954 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 28/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HCC1954 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 29/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HGF Signaling in Keratinocytes (W=2500,T=9740,T_burn=4400,T_window=5340,N=68). . .
# Progress: 30/74,	 maximum difference: 0.00023670411985016182,	 sum difference: 0.004773970037452823
# Simulating Model HH Pathway of Drosophila Signaling Pathways (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 31/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model HIV-1 interactions with T Cell Signalling Pathway (W=2500,T=13590,T_burn=7900,T_window=5690,N=138). . .
# Progress: 32/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Human Gonadal Sex Determination (W=2500,T=7045,T_burn=1950,T_window=5095,N=19). . .
# Progress: 33/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model IGVH mutations in chronic lymphocytic leukemia (W=2500,T=11005,T_burn=5550,T_window=5455,N=91). . .
# Progress: 34/74,	 maximum difference: 0.0015706691109074467,	 sum difference: 0.003760219981668242
# Simulating Model IL-1 Signaling (W=2500,T=12490,T_burn=6900,T_window=5590,N=118). . .
# Progress: 35/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model IL-6 Signalling (W=2500,T=10730,T_burn=5300,T_window=5430,N=86). . .
# Progress: 36/74,	 maximum difference: 0.0035524861878453162,	 sum difference: 0.07668913443830559
# Simulating Model Influenza A Virus Replication Cycle (W=2500,T=13205,T_burn=7550,T_window=5655,N=131). . .
# Progress: 37/74,	 maximum difference: 0.00021909814323607581,	 sum difference: 0.0013998231653404114
# Simulating Model Iron acquisition and oxidative stress response in aspergillus fumigatus (W=2500,T=7210,T_burn=2100,T_window=5110,N=22). . .
# Progress: 38/74,	 maximum difference: 0.003983561643835565,	 sum difference: 0.04008845401174202
# Simulating Model Lac Operon (W=2500,T=6715,T_burn=1650,T_window=5065,N=13). . .
# Progress: 39/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Lymphoid and myeloid cell specification and transdifferentiation (W=2500,T=7815,T_burn=2650,T_window=5165,N=33). . .
# Progress: 40/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Lymphopoiesis Regulatory Network (W=2500,T=10455,T_burn=5050,T_window=5405,N=81). . .
# Progress: 41/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model MAPK Cancer Cell Fate Network (W=2500,T=8915,T_burn=3650,T_window=5265,N=53). . .
# Progress: 42/74,	 maximum difference: 0.005098765432098792,	 sum difference: 0.09844976258309628
# Simulating Model Mammalian Cell Cycle (W=2500,T=7100,T_burn=2000,T_window=5100,N=20). . .
# Progress: 43/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Mammalian Cell Cycle 2006 (W=2500,T=6550,T_burn=1500,T_window=5050,N=10). . .
# Progress: 44/74,	 maximum difference: 0.0013651485148514775,	 sum difference: 0.005104752475247748
# Simulating Model Metabolic Interactions in the Gut Microbiome (W=2500,T=6660,T_burn=1600,T_window=5060,N=12). . .
# Progress: 45/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Neurotransmitter Signaling Pathway (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 46/74,	 maximum difference: 0.0031875984251967804,	 sum difference: 0.016029921259842754
# Simulating Model Oxidative Stress Pathway (W=2500,T=7045,T_burn=1950,T_window=5095,N=19). . .
# Progress: 47/74,	 maximum difference: 0.004451422963689833,	 sum difference: 0.026716977428852096
# Simulating Model PC12 Cell Differentiation (W=2500,T=9410,T_burn=4100,T_window=5310,N=62). . .
# Progress: 48/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Predicting Variabilities in Cardiac Gene (W=2500,T=6825,T_burn=1750,T_window=5075,N=15). . .
# Progress: 49/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 50/74,	 maximum difference: 0.00284405458089676,	 sum difference: 0.004316374269005996
# Simulating Model Processing of Spz Network from the Drosophila Signaling Pathway (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 51/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Regulation of the L-arabinose operon of Escherichia coli (W=2500,T=6715,T_burn=1650,T_window=5065,N=13). . .
# Progress: 52/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Long-term ErbB Network (W=2500,T=7375,T_burn=2250,T_window=5125,N=25). . .
# Progress: 53/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model SKBR3 Breast Cell Line Short-term ErbB Network (W=2500,T=6880,T_burn=1800,T_window=5080,N=16). . .
# Progress: 54/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Senescence Associated Secretory Phenotype (W=2500,T=8805,T_burn=3550,T_window=5255,N=51). . .
# Progress: 55/74,	 maximum difference: 0.0018584205518550334,	 sum difference: 0.009755470980019991
# Simulating Model Septation Initiation Network (W=2500,T=7705,T_burn=2550,T_window=5155,N=31). . .
# Progress: 56/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Signal Transduction in Fibroblasts (W=2500,T=150000,T_burn=50000,T_window=100000,N=139). . .
# Progress: 57/74,	 maximum difference: 0.003235419999994882,	 sum difference: 0.11910724999999497
# Simulating Model Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (W=2500,T=9630,T_burn=4300,T_window=5330,N=66). . .
# Progress: 58/74,	 maximum difference: 0.0033904315196998658,	 sum difference: 0.03875159474672008
# Simulating Model Signaling in Macrophage Activation (W=2500,T=23655,T_burn=17050,T_window=6605,N=321). . .
# Progress: 59/74,	 maximum difference: 0.005292051476154747,	 sum difference: 0.05114549583648897
# Simulating Model Stomatal Opening Model (W=2500,T=8695,T_burn=3450,T_window=5245,N=49). . .
# Progress: 60/74,	 maximum difference: 0.0018938036224975807,	 sum difference: 0.00243050524308841
# Simulating Model T Cell Receptor Signaling (W=2500,T=11555,T_burn=6050,T_window=5505,N=101). . .
# Progress: 61/74,	 maximum difference: 0.003392007266121714,	 sum difference: 0.03659727520435938
# Simulating Model T cell differentiation (W=2500,T=7265,T_burn=2150,T_window=5115,N=23). . .
# Progress: 62/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model T-Cell Signaling 2006 (W=2500,T=8200,T_burn=3000,T_window=5200,N=40). . .
# Progress: 63/74,	 maximum difference: 0.002038461538461527,	 sum difference: 0.027900961538463057
# Simulating Model T-LGL Survival Network 2008 (W=2500,T=9355,T_burn=4050,T_window=5305,N=61). . .
# Progress: 64/74,	 maximum difference: 0.0013114043355325067,	 sum difference: 0.015955890669178872
# Simulating Model T-LGL Survival Network 2011 (W=2500,T=9300,T_burn=4000,T_window=5300,N=60). . .
# Progress: 65/74,	 maximum difference: 0.00036396226415094483,	 sum difference: 0.001368867924528284
# Simulating Model T-LGL Survival Network 2011 Reduced Network (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 66/74,	 maximum difference: 0.0002669941060903652,	 sum difference: 0.0003607072691552138
# Simulating Model TOL Regulatory Network (W=2500,T=7320,T_burn=2200,T_window=5120,N=24). . .
# Progress: 67/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Toll Pathway of Drosophila Signaling Pathway (W=2500,T=6605,T_burn=1550,T_window=5055,N=11). . .
# Progress: 68/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Treatment of Castration-Resistant Prostate Cancer (W=2500,T=8310,T_burn=3100,T_window=5210,N=42). . .
# Progress: 69/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Trichostrongylus retortaeformis (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 70/74,	 maximum difference: 0.0007922027290448302,	 sum difference: 0.0028058479532163186
# Simulating Model Tumour Cell Invasion and Migration (W=2500,T=7760,T_burn=2600,T_window=5160,N=32). . .
# Progress: 71/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model VEGF Pathway of Drosophila Signaling Pathway (W=2500,T=6990,T_burn=1900,T_window=5090,N=18). . .
# Progress: 72/74,	 maximum difference: 0.0,	 sum difference: 0.0
# Simulating Model Wg Pathway of Drosophila Signalling Pathways (W=2500,T=7430,T_burn=2300,T_window=5130,N=26). . .
# Progress: 73/74,	 maximum difference: 0.00026393762183236913,	 sum difference: 0.0003859649122806689
# Simulating Model Yeast Apoptosis (W=2500,T=10015,T_burn=4650,T_window=5365,N=73). . .
# Progress: 74/74,	 maximum difference: 0.003714072693382975,	 sum difference: 0.006234109972040991

# %%
print(f'max max sync: {max(sync_convergence_measures.values())}')
print(f'max sum sycn: {max(sync_alt.values())}')
print(f'max max async: {max(async_convergence_measures.values())}')
print(f'max sum async: {max(async_alt.values())}')
# Out:
# max max sync: 0.0004964000000000635
# max sum sycn: 0.004335200000000039
# max max async: 0.006948369565216939
# max sum async: 0.11910724999999497

# %%
with open('./data/converged_average_node_values.csv','w') as f:
    for model_name, smodel, amodel in [(k,sync_models[k],async_models[k]) for k in sorted(async_models)]:
        straj = ','.join(map(lambda x: str(cp.round(x,3)),cp.mean(smodel.trajectories,axis=0)))
        atraj = ','.join(map(lambda x: str(cp.round(x,3)),cp.mean(amodel.trajectories,axis=0)))
        f.write(f'{model_name},{cp.round(sync_convergence_measures[model_name],3)},{cp.round(sync_alt[model_name],3)},synchronous,{straj}\n')
        f.write(f'{model_name},{cp.round(async_convergence_measures[model_name],3)},{cp.round(async_alt[model_name],3)},asynchronous,{atraj}\n')
