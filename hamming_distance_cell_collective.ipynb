# %%
import cubewalkers as cw
import cupy as cp
from copy import deepcopy

# %%
IMPORT_RULES_FROM_FILES = True
cc_models_dir = './models/cell_collective/'
if IMPORT_RULES_FROM_FILES:
    from os import listdir
    
    sync_models = {}
    for fname in listdir(cc_models_dir):
        with open(cc_models_dir+fname) as rulefile:
            name = fname.strip('.txt')
            rules = rulefile.read()
            sync_models[name]=cw.Model(rules)
else:
    from cana.datasets.bio import load_all_cell_collective_models
    def cell_collective_models():
        return {BN.name:cw.Model(cw.conversions.network_rules_from_cana(BN)) 
                for BN in load_all_cell_collective_models()}
    sync_models = cell_collective_models()
    for name,model in sync_models.items():
        with open(cc_models_dir+name+'.txt','w') as rulefile:
            rulefile.write(model.rules)

total_models = len(sync_models)
async_models = deepcopy(sync_models)

# %%
def hamming_distance_cell_coll(models, sync=True, T_synch=10, W=10000):
    hamming_distances = {}
    for model_idx, (model_name, model) in enumerate(models.items()):
        N = model.n_variables
        
        if sync:
            print(f"Calculating Hamming distances in synchronous for {model_name} (T={T_synch},{N=},{W=}). . .")
            model.n_time_steps = T_synch
            model.n_walkers = W // N
            derrida_synch = cp.zeros((model.n_time_steps+1))
            for node in model.vardict:
                di = model.dynamical_impact(source_var=node,maskfunction=cw.update_schemes.synchronous,threads_per_block=(16,16))
                di = cp.sum(di, axis=1)
                derrida_synch += di
            derrida_synch /= N
            hamming_distances[model_name] = derrida_synch
        else:
            print(f"Calculating Hamming distances in asynchronous for {model_name} (T={T_synch * N},{N=},{W=}). . .")
            model.n_time_steps = T_synch * N
            model.n_walkers = W // N
            derrida_asynch = cp.zeros((model.n_time_steps+1))
            for node in model.vardict:
                di = model.dynamical_impact(source_var=node,maskfunction=cw.update_schemes.asynchronous,threads_per_block=(16,16))
                di = cp.sum(di, axis=1)
                derrida_asynch += di
            derrida_asynch /= N
            hamming_distances[model_name] = derrida_asynch
        print(f"Progress: {(model_idx+1)}/{total_models}")
    return hamming_distances

# %%
sync_hamming_distances = hamming_distance_cell_coll(sync_models,sync=True)
# Out:
# Calculating Hamming distances in synchronous for Apoptosis Network (T=10,N=41,W=10000). . .
# Progress: 1/74
# Calculating Hamming distances in synchronous for Arabidopsis thaliana Cell Cycle (T=10,N=14,W=10000). . .
# Progress: 2/74
# Calculating Hamming distances in synchronous for Aurora Kinase A in Neuroblastoma (T=10,N=23,W=10000). . .
# Progress: 3/74
# Calculating Hamming distances in synchronous for B bronchiseptica and T retortaeformis coinfection (T=10,N=53,W=10000). . .
# Progress: 4/74
# Calculating Hamming distances in synchronous for B cell differentiation (T=10,N=22,W=10000). . .
# Progress: 5/74
# Calculating Hamming distances in synchronous for Bordetella bronchiseptica (T=10,N=33,W=10000). . .
# Progress: 6/74
# Calculating Hamming distances in synchronous for Bortezomib Responses in U266 Human Myeloma Cells (T=10,N=67,W=10000). . .
# Progress: 7/74
# Calculating Hamming distances in synchronous for BT474 Breast Cell Line Long-term ErbB Network (T=10,N=25,W=10000). . .
# Progress: 8/74
# Calculating Hamming distances in synchronous for BT474 Breast Cell Line Short-term ErbB Network (T=10,N=16,W=10000). . .
# Progress: 9/74
# Calculating Hamming distances in synchronous for Budding Yeast Cell Cycle 2009 (T=10,N=18,W=10000). . .
# Progress: 10/74
# Calculating Hamming distances in synchronous for Budding Yeast Cell Cycle (T=10,N=20,W=10000). . .
# Progress: 11/74
# Calculating Hamming distances in synchronous for Cardiac developmen (T=10,N=15,W=10000). . .
# Progress: 12/74
# Calculating Hamming distances in synchronous for CD4 T cell signaling (T=10,N=188,W=10000). . .
# Progress: 13/74
# Calculating Hamming distances in synchronous for CD4+ T Cell Differentiation and Plasticity (T=10,N=18,W=10000). . .
# Progress: 14/74
# Calculating Hamming distances in synchronous for CD4+ T cell Differentiation (T=10,N=38,W=10000). . .
# Progress: 15/74
# Calculating Hamming distances in synchronous for Cell Cycle Transcription by Coupled CDK and Network Oscillators (T=10,N=9,W=10000). . .
# Progress: 16/74
# Calculating Hamming distances in synchronous for Cholesterol Regulatory Pathway (T=10,N=34,W=10000). . .
# Progress: 17/74
# Calculating Hamming distances in synchronous for Colitis-associated colon cancer (T=10,N=70,W=10000). . .
# Progress: 18/74
# Calculating Hamming distances in synchronous for Cortical Area Developmen (T=10,N=5,W=10000). . .
# Progress: 19/74
# Calculating Hamming distances in synchronous for Death Receptor Signaling (T=10,N=28,W=10000). . .
# Progress: 20/74
# Calculating Hamming distances in synchronous for Differentiation of T lymphocytes (T=10,N=50,W=10000). . .
# Progress: 21/74
# Calculating Hamming distances in synchronous for EGFR & ErbB Signaling (T=10,N=104,W=10000). . .
# Progress: 22/74
# Calculating Hamming distances in synchronous for FA BRCA pathway (T=10,N=28,W=10000). . .
# Progress: 23/74
# Calculating Hamming distances in synchronous for Fanconi anemia and checkpoint recovery (T=10,N=15,W=10000). . .
# Progress: 24/74
# Calculating Hamming distances in synchronous for FGF pathway of Drosophila Signalling Pathways (T=10,N=23,W=10000). . .
# Progress: 25/74
# Calculating Hamming distances in synchronous for Glucose Repression Signaling 2009 (T=10,N=73,W=10000). . .
# Progress: 26/74
# Calculating Hamming distances in synchronous for Guard Cell Abscisic Acid Signaling (T=10,N=44,W=10000). . .
# Progress: 27/74
# Calculating Hamming distances in synchronous for HCC1954 Breast Cell Line Long-term ErbB Network (T=10,N=25,W=10000). . .
# Progress: 28/74
# Calculating Hamming distances in synchronous for HCC1954 Breast Cell Line Short-term ErbB Network (T=10,N=16,W=10000). . .
# Progress: 29/74
# Calculating Hamming distances in synchronous for HGF Signaling in Keratinocytes (T=10,N=68,W=10000). . .
# Progress: 30/74
# Calculating Hamming distances in synchronous for HH Pathway of Drosophila Signaling Pathways (T=10,N=24,W=10000). . .
# Progress: 31/74
# Calculating Hamming distances in synchronous for HIV-1 interactions with T Cell Signalling Pathway (T=10,N=138,W=10000). . .
# Progress: 32/74
# Calculating Hamming distances in synchronous for Human Gonadal Sex Determination (T=10,N=19,W=10000). . .
# Progress: 33/74
# Calculating Hamming distances in synchronous for IGVH mutations in chronic lymphocytic leukemia (T=10,N=91,W=10000). . .
# Progress: 34/74
# Calculating Hamming distances in synchronous for IL-1 Signaling (T=10,N=118,W=10000). . .
# Progress: 35/74
# Calculating Hamming distances in synchronous for IL-6 Signalling (T=10,N=86,W=10000). . .
# Progress: 36/74
# Calculating Hamming distances in synchronous for Influenza A Virus Replication Cycle (T=10,N=131,W=10000). . .
# Progress: 37/74
# Calculating Hamming distances in synchronous for Iron acquisition and oxidative stress response in aspergillus fumigatus (T=10,N=22,W=10000). . .
# Progress: 38/74
# Calculating Hamming distances in synchronous for Lac Operon (T=10,N=13,W=10000). . .
# Progress: 39/74
# Calculating Hamming distances in synchronous for Lymphoid and myeloid cell specification and transdifferentiation (T=10,N=33,W=10000). . .
# Progress: 40/74
# Calculating Hamming distances in synchronous for Lymphopoiesis Regulatory Network (T=10,N=81,W=10000). . .
# Progress: 41/74
# Calculating Hamming distances in synchronous for Mammalian Cell Cycle 2006 (T=10,N=10,W=10000). . .
# Progress: 42/74
# Calculating Hamming distances in synchronous for Mammalian Cell Cycle (T=10,N=20,W=10000). . .
# Progress: 43/74
# Calculating Hamming distances in synchronous for MAPK Cancer Cell Fate Network (T=10,N=53,W=10000). . .
# Progress: 44/74
# Calculating Hamming distances in synchronous for Metabolic Interactions in the Gut Microbiome (T=10,N=12,W=10000). . .
# Progress: 45/74
# Calculating Hamming distances in synchronous for Neurotransmitter Signaling Pathway (T=10,N=16,W=10000). . .
# Progress: 46/74
# Calculating Hamming distances in synchronous for Oxidative Stress Pathway (T=10,N=19,W=10000). . .
# Progress: 47/74
# Calculating Hamming distances in synchronous for PC12 Cell Differentiation (T=10,N=62,W=10000). . .
# Progress: 48/74
# Calculating Hamming distances in synchronous for Predicting Variabilities in Cardiac Gene (T=10,N=15,W=10000). . .
# Progress: 49/74
# Calculating Hamming distances in synchronous for Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (T=10,N=26,W=10000). . .
# Progress: 50/74
# Calculating Hamming distances in synchronous for Processing of Spz Network from the Drosophila Signaling Pathway (T=10,N=24,W=10000). . .
# Progress: 51/74
# Calculating Hamming distances in synchronous for Regulation of the L-arabinose operon of Escherichia coli (T=10,N=13,W=10000). . .
# Progress: 52/74
# Calculating Hamming distances in synchronous for Senescence Associated Secretory Phenotype (T=10,N=51,W=10000). . .
# Progress: 53/74
# Calculating Hamming distances in synchronous for Septation Initiation Network (T=10,N=31,W=10000). . .
# Progress: 54/74
# Calculating Hamming distances in synchronous for Signal Transduction in Fibroblasts (T=10,N=139,W=10000). . .
# Progress: 55/74
# Calculating Hamming distances in synchronous for Signaling in Macrophage Activation (T=10,N=321,W=10000). . .
# Progress: 56/74
# Calculating Hamming distances in synchronous for Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (T=10,N=66,W=10000). . .
# Progress: 57/74
# Calculating Hamming distances in synchronous for SKBR3 Breast Cell Line Long-term ErbB Network (T=10,N=25,W=10000). . .
# Progress: 58/74
# Calculating Hamming distances in synchronous for SKBR3 Breast Cell Line Short-term ErbB Network (T=10,N=16,W=10000). . .
# Progress: 59/74
# Calculating Hamming distances in synchronous for Stomatal Opening Model (T=10,N=49,W=10000). . .
# Progress: 60/74
# Calculating Hamming distances in synchronous for T cell differentiation (T=10,N=23,W=10000). . .
# Progress: 61/74
# Calculating Hamming distances in synchronous for T Cell Receptor Signaling (T=10,N=101,W=10000). . .
# Progress: 62/74
# Calculating Hamming distances in synchronous for T-Cell Signaling 2006 (T=10,N=40,W=10000). . .
# Progress: 63/74
# Calculating Hamming distances in synchronous for T-LGL Survival Network 2008 (T=10,N=61,W=10000). . .
# Progress: 64/74
# Calculating Hamming distances in synchronous for T-LGL Survival Network 2011 Reduced Network (T=10,N=18,W=10000). . .
# Progress: 65/74
# Calculating Hamming distances in synchronous for T-LGL Survival Network 2011 (T=10,N=60,W=10000). . .
# Progress: 66/74
# Calculating Hamming distances in synchronous for TOL Regulatory Network (T=10,N=24,W=10000). . .
# Progress: 67/74
# Calculating Hamming distances in synchronous for Toll Pathway of Drosophila Signaling Pathway (T=10,N=11,W=10000). . .
# Progress: 68/74
# Calculating Hamming distances in synchronous for Treatment of Castration-Resistant Prostate Cancer (T=10,N=42,W=10000). . .
# Progress: 69/74
# Calculating Hamming distances in synchronous for Trichostrongylus retortaeformis (T=10,N=26,W=10000). . .
# Progress: 70/74
# Calculating Hamming distances in synchronous for Tumour Cell Invasion and Migration (T=10,N=32,W=10000). . .
# Progress: 71/74
# Calculating Hamming distances in synchronous for VEGF Pathway of Drosophila Signaling Pathway (T=10,N=18,W=10000). . .
# Progress: 72/74
# Calculating Hamming distances in synchronous for Wg Pathway of Drosophila Signalling Pathways (T=10,N=26,W=10000). . .
# Progress: 73/74
# Calculating Hamming distances in synchronous for Yeast Apoptosis (T=10,N=73,W=10000). . .
# Progress: 74/74

# %%
async_hamming_distances = hamming_distance_cell_coll(sync_models,sync=False)
# Out:
# Calculating Hamming distances in asynchronous for Apoptosis Network (T=410,N=41,W=10000). . .
# Progress: 1/74
# Calculating Hamming distances in asynchronous for Arabidopsis thaliana Cell Cycle (T=140,N=14,W=10000). . .
# Progress: 2/74
# Calculating Hamming distances in asynchronous for Aurora Kinase A in Neuroblastoma (T=230,N=23,W=10000). . .
# Progress: 3/74
# Calculating Hamming distances in asynchronous for B bronchiseptica and T retortaeformis coinfection (T=530,N=53,W=10000). . .
# Progress: 4/74
# Calculating Hamming distances in asynchronous for B cell differentiation (T=220,N=22,W=10000). . .
# Progress: 5/74
# Calculating Hamming distances in asynchronous for Bordetella bronchiseptica (T=330,N=33,W=10000). . .
# Progress: 6/74
# Calculating Hamming distances in asynchronous for Bortezomib Responses in U266 Human Myeloma Cells (T=670,N=67,W=10000). . .
# Progress: 7/74
# Calculating Hamming distances in asynchronous for BT474 Breast Cell Line Long-term ErbB Network (T=250,N=25,W=10000). . .
# Progress: 8/74
# Calculating Hamming distances in asynchronous for BT474 Breast Cell Line Short-term ErbB Network (T=160,N=16,W=10000). . .
# Progress: 9/74
# Calculating Hamming distances in asynchronous for Budding Yeast Cell Cycle 2009 (T=180,N=18,W=10000). . .
# Progress: 10/74
# Calculating Hamming distances in asynchronous for Budding Yeast Cell Cycle (T=200,N=20,W=10000). . .
# Progress: 11/74
# Calculating Hamming distances in asynchronous for Cardiac developmen (T=150,N=15,W=10000). . .
# Progress: 12/74
# Calculating Hamming distances in asynchronous for CD4 T cell signaling (T=1880,N=188,W=10000). . .
# Progress: 13/74
# Calculating Hamming distances in asynchronous for CD4+ T Cell Differentiation and Plasticity (T=180,N=18,W=10000). . .
# Progress: 14/74
# Calculating Hamming distances in asynchronous for CD4+ T cell Differentiation (T=380,N=38,W=10000). . .
# Progress: 15/74
# Calculating Hamming distances in asynchronous for Cell Cycle Transcription by Coupled CDK and Network Oscillators (T=90,N=9,W=10000). . .
# Progress: 16/74
# Calculating Hamming distances in asynchronous for Cholesterol Regulatory Pathway (T=340,N=34,W=10000). . .
# Progress: 17/74
# Calculating Hamming distances in asynchronous for Colitis-associated colon cancer (T=700,N=70,W=10000). . .
# Progress: 18/74
# Calculating Hamming distances in asynchronous for Cortical Area Developmen (T=50,N=5,W=10000). . .
# Progress: 19/74
# Calculating Hamming distances in asynchronous for Death Receptor Signaling (T=280,N=28,W=10000). . .
# Progress: 20/74
# Calculating Hamming distances in asynchronous for Differentiation of T lymphocytes (T=500,N=50,W=10000). . .
# Progress: 21/74
# Calculating Hamming distances in asynchronous for EGFR & ErbB Signaling (T=1040,N=104,W=10000). . .
# Progress: 22/74
# Calculating Hamming distances in asynchronous for FA BRCA pathway (T=280,N=28,W=10000). . .
# Progress: 23/74
# Calculating Hamming distances in asynchronous for Fanconi anemia and checkpoint recovery (T=150,N=15,W=10000). . .
# Progress: 24/74
# Calculating Hamming distances in asynchronous for FGF pathway of Drosophila Signalling Pathways (T=230,N=23,W=10000). . .
# Progress: 25/74
# Calculating Hamming distances in asynchronous for Glucose Repression Signaling 2009 (T=730,N=73,W=10000). . .
# Progress: 26/74
# Calculating Hamming distances in asynchronous for Guard Cell Abscisic Acid Signaling (T=440,N=44,W=10000). . .
# Progress: 27/74
# Calculating Hamming distances in asynchronous for HCC1954 Breast Cell Line Long-term ErbB Network (T=250,N=25,W=10000). . .
# Progress: 28/74
# Calculating Hamming distances in asynchronous for HCC1954 Breast Cell Line Short-term ErbB Network (T=160,N=16,W=10000). . .
# Progress: 29/74
# Calculating Hamming distances in asynchronous for HGF Signaling in Keratinocytes (T=680,N=68,W=10000). . .
# Progress: 30/74
# Calculating Hamming distances in asynchronous for HH Pathway of Drosophila Signaling Pathways (T=240,N=24,W=10000). . .
# Progress: 31/74
# Calculating Hamming distances in asynchronous for HIV-1 interactions with T Cell Signalling Pathway (T=1380,N=138,W=10000). . .
# Progress: 32/74
# Calculating Hamming distances in asynchronous for Human Gonadal Sex Determination (T=190,N=19,W=10000). . .
# Progress: 33/74
# Calculating Hamming distances in asynchronous for IGVH mutations in chronic lymphocytic leukemia (T=910,N=91,W=10000). . .
# Progress: 34/74
# Calculating Hamming distances in asynchronous for IL-1 Signaling (T=1180,N=118,W=10000). . .
# Progress: 35/74
# Calculating Hamming distances in asynchronous for IL-6 Signalling (T=860,N=86,W=10000). . .
# Progress: 36/74
# Calculating Hamming distances in asynchronous for Influenza A Virus Replication Cycle (T=1310,N=131,W=10000). . .
# Progress: 37/74
# Calculating Hamming distances in asynchronous for Iron acquisition and oxidative stress response in aspergillus fumigatus (T=220,N=22,W=10000). . .
# Progress: 38/74
# Calculating Hamming distances in asynchronous for Lac Operon (T=130,N=13,W=10000). . .
# Progress: 39/74
# Calculating Hamming distances in asynchronous for Lymphoid and myeloid cell specification and transdifferentiation (T=330,N=33,W=10000). . .
# Progress: 40/74
# Calculating Hamming distances in asynchronous for Lymphopoiesis Regulatory Network (T=810,N=81,W=10000). . .
# Progress: 41/74
# Calculating Hamming distances in asynchronous for Mammalian Cell Cycle 2006 (T=100,N=10,W=10000). . .
# Progress: 42/74
# Calculating Hamming distances in asynchronous for Mammalian Cell Cycle (T=200,N=20,W=10000). . .
# Progress: 43/74
# Calculating Hamming distances in asynchronous for MAPK Cancer Cell Fate Network (T=530,N=53,W=10000). . .
# Progress: 44/74
# Calculating Hamming distances in asynchronous for Metabolic Interactions in the Gut Microbiome (T=120,N=12,W=10000). . .
# Progress: 45/74
# Calculating Hamming distances in asynchronous for Neurotransmitter Signaling Pathway (T=160,N=16,W=10000). . .
# Progress: 46/74
# Calculating Hamming distances in asynchronous for Oxidative Stress Pathway (T=190,N=19,W=10000). . .
# Progress: 47/74
# Calculating Hamming distances in asynchronous for PC12 Cell Differentiation (T=620,N=62,W=10000). . .
# Progress: 48/74
# Calculating Hamming distances in asynchronous for Predicting Variabilities in Cardiac Gene (T=150,N=15,W=10000). . .
# Progress: 49/74
# Calculating Hamming distances in asynchronous for Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (T=260,N=26,W=10000). . .
# Progress: 50/74
# Calculating Hamming distances in asynchronous for Processing of Spz Network from the Drosophila Signaling Pathway (T=240,N=24,W=10000). . .
# Progress: 51/74
# Calculating Hamming distances in asynchronous for Regulation of the L-arabinose operon of Escherichia coli (T=130,N=13,W=10000). . .
# Progress: 52/74
# Calculating Hamming distances in asynchronous for Senescence Associated Secretory Phenotype (T=510,N=51,W=10000). . .
# Progress: 53/74
# Calculating Hamming distances in asynchronous for Septation Initiation Network (T=310,N=31,W=10000). . .
# Progress: 54/74
# Calculating Hamming distances in asynchronous for Signal Transduction in Fibroblasts (T=1390,N=139,W=10000). . .
# Progress: 55/74
# Calculating Hamming distances in asynchronous for Signaling in Macrophage Activation (T=3210,N=321,W=10000). . .
# Progress: 56/74
# Calculating Hamming distances in asynchronous for Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (T=660,N=66,W=10000). . .
# Progress: 57/74
# Calculating Hamming distances in asynchronous for SKBR3 Breast Cell Line Long-term ErbB Network (T=250,N=25,W=10000). . .
# Progress: 58/74
# Calculating Hamming distances in asynchronous for SKBR3 Breast Cell Line Short-term ErbB Network (T=160,N=16,W=10000). . .
# Progress: 59/74
# Calculating Hamming distances in asynchronous for Stomatal Opening Model (T=490,N=49,W=10000). . .
# Progress: 60/74
# Calculating Hamming distances in asynchronous for T cell differentiation (T=230,N=23,W=10000). . .
# Progress: 61/74
# Calculating Hamming distances in asynchronous for T Cell Receptor Signaling (T=1010,N=101,W=10000). . .
# Progress: 62/74
# Calculating Hamming distances in asynchronous for T-Cell Signaling 2006 (T=400,N=40,W=10000). . .
# Progress: 63/74
# Calculating Hamming distances in asynchronous for T-LGL Survival Network 2008 (T=610,N=61,W=10000). . .
# Progress: 64/74
# Calculating Hamming distances in asynchronous for T-LGL Survival Network 2011 Reduced Network (T=180,N=18,W=10000). . .
# Progress: 65/74
# Calculating Hamming distances in asynchronous for T-LGL Survival Network 2011 (T=600,N=60,W=10000). . .
# Progress: 66/74
# Calculating Hamming distances in asynchronous for TOL Regulatory Network (T=240,N=24,W=10000). . .
# Progress: 67/74
# Calculating Hamming distances in asynchronous for Toll Pathway of Drosophila Signaling Pathway (T=110,N=11,W=10000). . .
# Progress: 68/74
# Calculating Hamming distances in asynchronous for Treatment of Castration-Resistant Prostate Cancer (T=420,N=42,W=10000). . .
# Progress: 69/74
# Calculating Hamming distances in asynchronous for Trichostrongylus retortaeformis (T=260,N=26,W=10000). . .
# Progress: 70/74
# Calculating Hamming distances in asynchronous for Tumour Cell Invasion and Migration (T=320,N=32,W=10000). . .
# Progress: 71/74
# Calculating Hamming distances in asynchronous for VEGF Pathway of Drosophila Signaling Pathway (T=180,N=18,W=10000). . .
# Progress: 72/74
# Calculating Hamming distances in asynchronous for Wg Pathway of Drosophila Signalling Pathways (T=260,N=26,W=10000). . .
# Progress: 73/74
# Calculating Hamming distances in asynchronous for Yeast Apoptosis (T=730,N=73,W=10000). . .
# Progress: 74/74

# %%
with open('./data/hamming_distances.csv','w') as f:
    for model_name in sorted(sync_models):
        shd = ','.join(map(lambda x: str(cp.round(x,3)),sync_hamming_distances[model_name]))
        ahd = ','.join(map(lambda x: str(cp.round(x,3)),async_hamming_distances[model_name]))
        f.write(f'{model_name},synchronous,{shd}\n')
        f.write(f'{model_name},asynchronous,{ahd}\n')

# %%
models_to_plot = []
for model_name in sorted(sync_models):
    shd = sync_hamming_distances[model_name]
    ahd = async_hamming_distances[model_name]
    if any(value > 1.1 for value in shd) and any(value < 0.9 for value in shd):
        models_to_plot.append(model_name)
    elif any(value > 1.1 for value in ahd) and any(value < 0.9 for value in ahd):
        models_to_plot.append(model_name)

print(models_to_plot)
# Out:
# ['FA BRCA pathway', 'Lymphoid and myeloid cell specification and transdifferentiation', 'Mammalian Cell Cycle 2006', 'Tumour Cell Invasion and Migration']

# %%
import matplotlib.pyplot as plt
import numpy as np

for model in models_to_plot:
    x2 = list(range(len(async_hamming_distances[model])))
    x1 = x2[::len(async_hamming_distances[model])//10]
    y = [float(i) for i in sync_hamming_distances[model]]
    z = [float(i) for i in async_hamming_distances[model]]

    plt.scatter(x1, y)
    plt.scatter(x2, z,s=1)
    plt.title(model)
    plt.xlabel('time steps in asynchronous')
    plt.ylabel('average Hamming distance')
    plt.axis([None, None, 0.6, 1.4])
    plt.show()
