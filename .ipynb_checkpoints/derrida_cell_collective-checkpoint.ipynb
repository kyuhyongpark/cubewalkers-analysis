# %%
import cubewalkers as cw
import cupy as cp
from copy import deepcopy

# %%
IMPORT_RULES_FROM_FILES = True
cc_models_dir = './models/cell_collective/'
if IMPORT_RULES_FROM_FILES:
    from os import listdir
    
    sync_models = {}
    for fname in listdir(cc_models_dir):
        with open(cc_models_dir+fname) as rulefile:
            name = fname.strip('.txt')
            rules = rulefile.read()
            sync_models[name]=cw.Model(rules)
else:
    from cana.datasets.bio import load_all_cell_collective_models
    def cell_collective_models():
        return {BN.name:cw.Model(cw.conversions.network_rules_from_cana(BN)) 
                for BN in load_all_cell_collective_models()}
    sync_models = cell_collective_models()
    for name,model in sync_models.items():
        with open(cc_models_dir+name+'.txt','w') as rulefile:
            rulefile.write(model.rules)

total_models = len(sync_models)
async_models = deepcopy(sync_models)

# %%
def derrida_cell_coll(models, sync=True ,W=10000):
    derrida_coefficients = {}
    for model_idx, (model_name, model) in enumerate(models.items()):
        N = model.n_variables
        
        if sync:
            print(f"Calculating Derrida coefficient in synchronous for {model_name} ({N=},{W=}). . .")
            model.n_walkers = W
            derrida_coefficients[model_name] = float(model.derrida_coefficient(threads_per_block=(16,16)))
        else:
            print(f"Calculating Derrida coefficient in asynchronous for {model_name} ({N=},{W=}). . .")
            model.n_time_steps = N
            model.n_walkers = W // N
            derrida_asynch = cp.zeros((N+1))
            for node in model.vardict:
                di = model.dynamical_impact(source_var=node,maskfunction=cw.update_schemes.asynchronous,threads_per_block=(16,16))
                di = cp.sum(di, axis=1)
                derrida_asynch += di
            derrida_asynch /= N
            derrida_coefficients[model_name] = float(derrida_asynch[-1])
            
        print(f"Progress: {(model_idx+1)}/{total_models}")
    return derrida_coefficients

# %%
sync_derrida_coefficients = derrida_cell_coll(sync_models,sync=True)
# Out:
# Calculating Derrida coefficient in synchronous for Apoptosis Network (N=41,W=10000). . .
# Progress: 1/74
# Calculating Derrida coefficient in synchronous for Arabidopsis thaliana Cell Cycle (N=14,W=10000). . .
# Progress: 2/74
# Calculating Derrida coefficient in synchronous for Aurora Kinase A in Neuroblastoma (N=23,W=10000). . .
# Progress: 3/74
# Calculating Derrida coefficient in synchronous for B bronchiseptica and T retortaeformis coinfection (N=53,W=10000). . .
# Progress: 4/74
# Calculating Derrida coefficient in synchronous for B cell differentiation (N=22,W=10000). . .
# Progress: 5/74
# Calculating Derrida coefficient in synchronous for Bordetella bronchiseptica (N=33,W=10000). . .
# Progress: 6/74
# Calculating Derrida coefficient in synchronous for Bortezomib Responses in U266 Human Myeloma Cells (N=67,W=10000). . .
# Progress: 7/74
# Calculating Derrida coefficient in synchronous for BT474 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 8/74
# Calculating Derrida coefficient in synchronous for BT474 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 9/74
# Calculating Derrida coefficient in synchronous for Budding Yeast Cell Cycle 2009 (N=18,W=10000). . .
# Progress: 10/74
# Calculating Derrida coefficient in synchronous for Budding Yeast Cell Cycle (N=20,W=10000). . .
# Progress: 11/74
# Calculating Derrida coefficient in synchronous for Cardiac developmen (N=15,W=10000). . .
# Progress: 12/74
# Calculating Derrida coefficient in synchronous for CD4 T cell signaling (N=188,W=10000). . .
# Progress: 13/74
# Calculating Derrida coefficient in synchronous for CD4+ T Cell Differentiation and Plasticity (N=18,W=10000). . .
# Progress: 14/74
# Calculating Derrida coefficient in synchronous for CD4+ T cell Differentiation (N=38,W=10000). . .
# Progress: 15/74
# Calculating Derrida coefficient in synchronous for Cell Cycle Transcription by Coupled CDK and Network Oscillators (N=9,W=10000). . .
# Progress: 16/74
# Calculating Derrida coefficient in synchronous for Cholesterol Regulatory Pathway (N=34,W=10000). . .
# Progress: 17/74
# Calculating Derrida coefficient in synchronous for Colitis-associated colon cancer (N=70,W=10000). . .
# Progress: 18/74
# Calculating Derrida coefficient in synchronous for Cortical Area Developmen (N=5,W=10000). . .
# Progress: 19/74
# Calculating Derrida coefficient in synchronous for Death Receptor Signaling (N=28,W=10000). . .
# Progress: 20/74
# Calculating Derrida coefficient in synchronous for Differentiation of T lymphocytes (N=50,W=10000). . .
# Progress: 21/74
# Calculating Derrida coefficient in synchronous for EGFR & ErbB Signaling (N=104,W=10000). . .
# Progress: 22/74
# Calculating Derrida coefficient in synchronous for FA BRCA pathway (N=28,W=10000). . .
# Progress: 23/74
# Calculating Derrida coefficient in synchronous for Fanconi anemia and checkpoint recovery (N=15,W=10000). . .
# Progress: 24/74
# Calculating Derrida coefficient in synchronous for FGF pathway of Drosophila Signalling Pathways (N=23,W=10000). . .
# Progress: 25/74
# Calculating Derrida coefficient in synchronous for Glucose Repression Signaling 2009 (N=73,W=10000). . .
# Progress: 26/74
# Calculating Derrida coefficient in synchronous for Guard Cell Abscisic Acid Signaling (N=44,W=10000). . .
# Progress: 27/74
# Calculating Derrida coefficient in synchronous for HCC1954 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 28/74
# Calculating Derrida coefficient in synchronous for HCC1954 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 29/74
# Calculating Derrida coefficient in synchronous for HGF Signaling in Keratinocytes (N=68,W=10000). . .
# Progress: 30/74
# Calculating Derrida coefficient in synchronous for HH Pathway of Drosophila Signaling Pathways (N=24,W=10000). . .
# Progress: 31/74
# Calculating Derrida coefficient in synchronous for HIV-1 interactions with T Cell Signalling Pathway (N=138,W=10000). . .
# Progress: 32/74
# Calculating Derrida coefficient in synchronous for Human Gonadal Sex Determination (N=19,W=10000). . .
# Progress: 33/74
# Calculating Derrida coefficient in synchronous for IGVH mutations in chronic lymphocytic leukemia (N=91,W=10000). . .
# Progress: 34/74
# Calculating Derrida coefficient in synchronous for IL-1 Signaling (N=118,W=10000). . .
# Progress: 35/74
# Calculating Derrida coefficient in synchronous for IL-6 Signalling (N=86,W=10000). . .
# Progress: 36/74
# Calculating Derrida coefficient in synchronous for Influenza A Virus Replication Cycle (N=131,W=10000). . .
# Progress: 37/74
# Calculating Derrida coefficient in synchronous for Iron acquisition and oxidative stress response in aspergillus fumigatus (N=22,W=10000). . .
# Progress: 38/74
# Calculating Derrida coefficient in synchronous for Lac Operon (N=13,W=10000). . .
# Progress: 39/74
# Calculating Derrida coefficient in synchronous for Lymphoid and myeloid cell specification and transdifferentiation (N=33,W=10000). . .
# Progress: 40/74
# Calculating Derrida coefficient in synchronous for Lymphopoiesis Regulatory Network (N=81,W=10000). . .
# Progress: 41/74
# Calculating Derrida coefficient in synchronous for Mammalian Cell Cycle 2006 (N=10,W=10000). . .
# Progress: 42/74
# Calculating Derrida coefficient in synchronous for Mammalian Cell Cycle (N=20,W=10000). . .
# Progress: 43/74
# Calculating Derrida coefficient in synchronous for MAPK Cancer Cell Fate Network (N=53,W=10000). . .
# Progress: 44/74
# Calculating Derrida coefficient in synchronous for Metabolic Interactions in the Gut Microbiome (N=12,W=10000). . .
# Progress: 45/74
# Calculating Derrida coefficient in synchronous for Neurotransmitter Signaling Pathway (N=16,W=10000). . .
# Progress: 46/74
# Calculating Derrida coefficient in synchronous for Oxidative Stress Pathway (N=19,W=10000). . .
# Progress: 47/74
# Calculating Derrida coefficient in synchronous for PC12 Cell Differentiation (N=62,W=10000). . .
# Progress: 48/74
# Calculating Derrida coefficient in synchronous for Predicting Variabilities in Cardiac Gene (N=15,W=10000). . .
# Progress: 49/74
# Calculating Derrida coefficient in synchronous for Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (N=26,W=10000). . .
# Progress: 50/74
# Calculating Derrida coefficient in synchronous for Processing of Spz Network from the Drosophila Signaling Pathway (N=24,W=10000). . .
# Progress: 51/74
# Calculating Derrida coefficient in synchronous for Regulation of the L-arabinose operon of Escherichia coli (N=13,W=10000). . .
# Progress: 52/74
# Calculating Derrida coefficient in synchronous for Senescence Associated Secretory Phenotype (N=51,W=10000). . .
# Progress: 53/74
# Calculating Derrida coefficient in synchronous for Septation Initiation Network (N=31,W=10000). . .
# Progress: 54/74
# Calculating Derrida coefficient in synchronous for Signal Transduction in Fibroblasts (N=139,W=10000). . .
# Progress: 55/74
# Calculating Derrida coefficient in synchronous for Signaling in Macrophage Activation (N=321,W=10000). . .
# Progress: 56/74
# Calculating Derrida coefficient in synchronous for Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (N=66,W=10000). . .
# Progress: 57/74
# Calculating Derrida coefficient in synchronous for SKBR3 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 58/74
# Calculating Derrida coefficient in synchronous for SKBR3 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 59/74
# Calculating Derrida coefficient in synchronous for Stomatal Opening Model (N=49,W=10000). . .
# Progress: 60/74
# Calculating Derrida coefficient in synchronous for T cell differentiation (N=23,W=10000). . .
# Progress: 61/74
# Calculating Derrida coefficient in synchronous for T Cell Receptor Signaling (N=101,W=10000). . .
# Progress: 62/74
# Calculating Derrida coefficient in synchronous for T-Cell Signaling 2006 (N=40,W=10000). . .
# Progress: 63/74
# Calculating Derrida coefficient in synchronous for T-LGL Survival Network 2008 (N=61,W=10000). . .
# Progress: 64/74
# Calculating Derrida coefficient in synchronous for T-LGL Survival Network 2011 Reduced Network (N=18,W=10000). . .
# Progress: 65/74
# Calculating Derrida coefficient in synchronous for T-LGL Survival Network 2011 (N=60,W=10000). . .
# Progress: 66/74
# Calculating Derrida coefficient in synchronous for TOL Regulatory Network (N=24,W=10000). . .
# Progress: 67/74
# Calculating Derrida coefficient in synchronous for Toll Pathway of Drosophila Signaling Pathway (N=11,W=10000). . .
# Progress: 68/74
# Calculating Derrida coefficient in synchronous for Treatment of Castration-Resistant Prostate Cancer (N=42,W=10000). . .
# Progress: 69/74
# Calculating Derrida coefficient in synchronous for Trichostrongylus retortaeformis (N=26,W=10000). . .
# Progress: 70/74
# Calculating Derrida coefficient in synchronous for Tumour Cell Invasion and Migration (N=32,W=10000). . .
# Progress: 71/74
# Calculating Derrida coefficient in synchronous for VEGF Pathway of Drosophila Signaling Pathway (N=18,W=10000). . .
# Progress: 72/74
# Calculating Derrida coefficient in synchronous for Wg Pathway of Drosophila Signalling Pathways (N=26,W=10000). . .
# Progress: 73/74
# Calculating Derrida coefficient in synchronous for Yeast Apoptosis (N=73,W=10000). . .
# Progress: 74/74

# %%
async_derrida_coefficients = derrida_cell_coll(sync_models,sync=False)
# Out:
# Calculating Derrida coefficient in asynchronous for Apoptosis Network (N=41,W=10000). . .
# Progress: 1/74
# Calculating Derrida coefficient in asynchronous for Arabidopsis thaliana Cell Cycle (N=14,W=10000). . .
# Progress: 2/74
# Calculating Derrida coefficient in asynchronous for Aurora Kinase A in Neuroblastoma (N=23,W=10000). . .
# Progress: 3/74
# Calculating Derrida coefficient in asynchronous for B bronchiseptica and T retortaeformis coinfection (N=53,W=10000). . .
# Progress: 4/74
# Calculating Derrida coefficient in asynchronous for B cell differentiation (N=22,W=10000). . .
# Progress: 5/74
# Calculating Derrida coefficient in asynchronous for Bordetella bronchiseptica (N=33,W=10000). . .
# Progress: 6/74
# Calculating Derrida coefficient in asynchronous for Bortezomib Responses in U266 Human Myeloma Cells (N=67,W=10000). . .
# Progress: 7/74
# Calculating Derrida coefficient in asynchronous for BT474 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 8/74
# Calculating Derrida coefficient in asynchronous for BT474 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 9/74
# Calculating Derrida coefficient in asynchronous for Budding Yeast Cell Cycle 2009 (N=18,W=10000). . .
# Progress: 10/74
# Calculating Derrida coefficient in asynchronous for Budding Yeast Cell Cycle (N=20,W=10000). . .
# Progress: 11/74
# Calculating Derrida coefficient in asynchronous for Cardiac developmen (N=15,W=10000). . .
# Progress: 12/74
# Calculating Derrida coefficient in asynchronous for CD4 T cell signaling (N=188,W=10000). . .
# Progress: 13/74
# Calculating Derrida coefficient in asynchronous for CD4+ T Cell Differentiation and Plasticity (N=18,W=10000). . .
# Progress: 14/74
# Calculating Derrida coefficient in asynchronous for CD4+ T cell Differentiation (N=38,W=10000). . .
# Progress: 15/74
# Calculating Derrida coefficient in asynchronous for Cell Cycle Transcription by Coupled CDK and Network Oscillators (N=9,W=10000). . .
# Progress: 16/74
# Calculating Derrida coefficient in asynchronous for Cholesterol Regulatory Pathway (N=34,W=10000). . .
# Progress: 17/74
# Calculating Derrida coefficient in asynchronous for Colitis-associated colon cancer (N=70,W=10000). . .
# Progress: 18/74
# Calculating Derrida coefficient in asynchronous for Cortical Area Developmen (N=5,W=10000). . .
# Progress: 19/74
# Calculating Derrida coefficient in asynchronous for Death Receptor Signaling (N=28,W=10000). . .
# Progress: 20/74
# Calculating Derrida coefficient in asynchronous for Differentiation of T lymphocytes (N=50,W=10000). . .
# Progress: 21/74
# Calculating Derrida coefficient in asynchronous for EGFR & ErbB Signaling (N=104,W=10000). . .
# Progress: 22/74
# Calculating Derrida coefficient in asynchronous for FA BRCA pathway (N=28,W=10000). . .
# Progress: 23/74
# Calculating Derrida coefficient in asynchronous for Fanconi anemia and checkpoint recovery (N=15,W=10000). . .
# Progress: 24/74
# Calculating Derrida coefficient in asynchronous for FGF pathway of Drosophila Signalling Pathways (N=23,W=10000). . .
# Progress: 25/74
# Calculating Derrida coefficient in asynchronous for Glucose Repression Signaling 2009 (N=73,W=10000). . .
# Progress: 26/74
# Calculating Derrida coefficient in asynchronous for Guard Cell Abscisic Acid Signaling (N=44,W=10000). . .
# Progress: 27/74
# Calculating Derrida coefficient in asynchronous for HCC1954 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 28/74
# Calculating Derrida coefficient in asynchronous for HCC1954 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 29/74
# Calculating Derrida coefficient in asynchronous for HGF Signaling in Keratinocytes (N=68,W=10000). . .
# Progress: 30/74
# Calculating Derrida coefficient in asynchronous for HH Pathway of Drosophila Signaling Pathways (N=24,W=10000). . .
# Progress: 31/74
# Calculating Derrida coefficient in asynchronous for HIV-1 interactions with T Cell Signalling Pathway (N=138,W=10000). . .
# Progress: 32/74
# Calculating Derrida coefficient in asynchronous for Human Gonadal Sex Determination (N=19,W=10000). . .
# Progress: 33/74
# Calculating Derrida coefficient in asynchronous for IGVH mutations in chronic lymphocytic leukemia (N=91,W=10000). . .
# Progress: 34/74
# Calculating Derrida coefficient in asynchronous for IL-1 Signaling (N=118,W=10000). . .
# Progress: 35/74
# Calculating Derrida coefficient in asynchronous for IL-6 Signalling (N=86,W=10000). . .
# Progress: 36/74
# Calculating Derrida coefficient in asynchronous for Influenza A Virus Replication Cycle (N=131,W=10000). . .
# Progress: 37/74
# Calculating Derrida coefficient in asynchronous for Iron acquisition and oxidative stress response in aspergillus fumigatus (N=22,W=10000). . .
# Progress: 38/74
# Calculating Derrida coefficient in asynchronous for Lac Operon (N=13,W=10000). . .
# Progress: 39/74
# Calculating Derrida coefficient in asynchronous for Lymphoid and myeloid cell specification and transdifferentiation (N=33,W=10000). . .
# Progress: 40/74
# Calculating Derrida coefficient in asynchronous for Lymphopoiesis Regulatory Network (N=81,W=10000). . .
# Progress: 41/74
# Calculating Derrida coefficient in asynchronous for Mammalian Cell Cycle 2006 (N=10,W=10000). . .
# Progress: 42/74
# Calculating Derrida coefficient in asynchronous for Mammalian Cell Cycle (N=20,W=10000). . .
# Progress: 43/74
# Calculating Derrida coefficient in asynchronous for MAPK Cancer Cell Fate Network (N=53,W=10000). . .
# Progress: 44/74
# Calculating Derrida coefficient in asynchronous for Metabolic Interactions in the Gut Microbiome (N=12,W=10000). . .
# Progress: 45/74
# Calculating Derrida coefficient in asynchronous for Neurotransmitter Signaling Pathway (N=16,W=10000). . .
# Progress: 46/74
# Calculating Derrida coefficient in asynchronous for Oxidative Stress Pathway (N=19,W=10000). . .
# Progress: 47/74
# Calculating Derrida coefficient in asynchronous for PC12 Cell Differentiation (N=62,W=10000). . .
# Progress: 48/74
# Calculating Derrida coefficient in asynchronous for Predicting Variabilities in Cardiac Gene (N=15,W=10000). . .
# Progress: 49/74
# Calculating Derrida coefficient in asynchronous for Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia (N=26,W=10000). . .
# Progress: 50/74
# Calculating Derrida coefficient in asynchronous for Processing of Spz Network from the Drosophila Signaling Pathway (N=24,W=10000). . .
# Progress: 51/74
# Calculating Derrida coefficient in asynchronous for Regulation of the L-arabinose operon of Escherichia coli (N=13,W=10000). . .
# Progress: 52/74
# Calculating Derrida coefficient in asynchronous for Senescence Associated Secretory Phenotype (N=51,W=10000). . .
# Progress: 53/74
# Calculating Derrida coefficient in asynchronous for Septation Initiation Network (N=31,W=10000). . .
# Progress: 54/74
# Calculating Derrida coefficient in asynchronous for Signal Transduction in Fibroblasts (N=139,W=10000). . .
# Progress: 55/74
# Calculating Derrida coefficient in asynchronous for Signaling in Macrophage Activation (N=321,W=10000). . .
# Progress: 56/74
# Calculating Derrida coefficient in asynchronous for Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598 (N=66,W=10000). . .
# Progress: 57/74
# Calculating Derrida coefficient in asynchronous for SKBR3 Breast Cell Line Long-term ErbB Network (N=25,W=10000). . .
# Progress: 58/74
# Calculating Derrida coefficient in asynchronous for SKBR3 Breast Cell Line Short-term ErbB Network (N=16,W=10000). . .
# Progress: 59/74
# Calculating Derrida coefficient in asynchronous for Stomatal Opening Model (N=49,W=10000). . .
# Progress: 60/74
# Calculating Derrida coefficient in asynchronous for T cell differentiation (N=23,W=10000). . .
# Progress: 61/74
# Calculating Derrida coefficient in asynchronous for T Cell Receptor Signaling (N=101,W=10000). . .
# Progress: 62/74
# Calculating Derrida coefficient in asynchronous for T-Cell Signaling 2006 (N=40,W=10000). . .
# Progress: 63/74
# Calculating Derrida coefficient in asynchronous for T-LGL Survival Network 2008 (N=61,W=10000). . .
# Progress: 64/74
# Calculating Derrida coefficient in asynchronous for T-LGL Survival Network 2011 Reduced Network (N=18,W=10000). . .
# Progress: 65/74
# Calculating Derrida coefficient in asynchronous for T-LGL Survival Network 2011 (N=60,W=10000). . .
# Progress: 66/74
# Calculating Derrida coefficient in asynchronous for TOL Regulatory Network (N=24,W=10000). . .
# Progress: 67/74
# Calculating Derrida coefficient in asynchronous for Toll Pathway of Drosophila Signaling Pathway (N=11,W=10000). . .
# Progress: 68/74
# Calculating Derrida coefficient in asynchronous for Treatment of Castration-Resistant Prostate Cancer (N=42,W=10000). . .
# Progress: 69/74
# Calculating Derrida coefficient in asynchronous for Trichostrongylus retortaeformis (N=26,W=10000). . .
# Progress: 70/74
# Calculating Derrida coefficient in asynchronous for Tumour Cell Invasion and Migration (N=32,W=10000). . .
# Progress: 71/74
# Calculating Derrida coefficient in asynchronous for VEGF Pathway of Drosophila Signaling Pathway (N=18,W=10000). . .
# Progress: 72/74
# Calculating Derrida coefficient in asynchronous for Wg Pathway of Drosophila Signalling Pathways (N=26,W=10000). . .
# Progress: 73/74
# Calculating Derrida coefficient in asynchronous for Yeast Apoptosis (N=73,W=10000). . .
# Progress: 74/74

# %%
for model_name in sorted(sync_models):
    print(f'{model_name},synchronous,{round(sync_derrida_coefficients[model_name],3)},asynchronous,{round(async_derrida_coefficients[model_name],3)}')
# Out:
# Apoptosis Network,synchronous,0.997,asynchronous,1.032
# Arabidopsis thaliana Cell Cycle,synchronous,1.274,asynchronous,1.242
# Aurora Kinase A in Neuroblastoma,synchronous,1.067,asynchronous,1.054
# B bronchiseptica and T retortaeformis coinfection,synchronous,1.006,asynchronous,1.009
# B cell differentiation,synchronous,0.998,asynchronous,1.017
# BT474 Breast Cell Line Long-term ErbB Network,synchronous,0.946,asynchronous,0.909
# BT474 Breast Cell Line Short-term ErbB Network,synchronous,0.777,asynchronous,0.82
# Bordetella bronchiseptica,synchronous,1.0,asynchronous,0.978
# Bortezomib Responses in U266 Human Myeloma Cells,synchronous,0.977,asynchronous,0.999
# Budding Yeast Cell Cycle,synchronous,1.018,asynchronous,1.022
# Budding Yeast Cell Cycle 2009,synchronous,1.115,asynchronous,1.105
# CD4 T cell signaling,synchronous,0.976,asynchronous,0.981
# CD4+ T Cell Differentiation and Plasticity,synchronous,0.717,asynchronous,0.893
# CD4+ T cell Differentiation,synchronous,0.985,asynchronous,0.997
# Cardiac developmen,synchronous,1.013,asynchronous,1.014
# Cell Cycle Transcription by Coupled CDK and Network Oscillators,synchronous,0.955,asynchronous,0.882
# Cholesterol Regulatory Pathway,synchronous,0.996,asynchronous,0.993
# Colitis-associated colon cancer,synchronous,1.003,asynchronous,1.017
# Cortical Area Developmen,synchronous,0.784,asynchronous,0.936
# Death Receptor Signaling,synchronous,1.034,asynchronous,1.032
# Differentiation of T lymphocytes,synchronous,0.966,asynchronous,0.97
# EGFR & ErbB Signaling,synchronous,0.945,asynchronous,0.969
# FA BRCA pathway,synchronous,1.047,asynchronous,1.017
# FGF pathway of Drosophila Signalling Pathways,synchronous,0.985,asynchronous,0.994
# Fanconi anemia and checkpoint recovery,synchronous,0.989,asynchronous,0.972
# Glucose Repression Signaling 2009,synchronous,1.006,asynchronous,1.003
# Guard Cell Abscisic Acid Signaling,synchronous,1.011,asynchronous,1.012
# HCC1954 Breast Cell Line Long-term ErbB Network,synchronous,0.959,asynchronous,0.943
# HCC1954 Breast Cell Line Short-term ErbB Network,synchronous,0.787,asynchronous,0.841
# HGF Signaling in Keratinocytes,synchronous,0.998,asynchronous,0.986
# HH Pathway of Drosophila Signaling Pathways,synchronous,0.922,asynchronous,0.952
# HIV-1 interactions with T Cell Signalling Pathway,synchronous,0.954,asynchronous,0.901
# Human Gonadal Sex Determination,synchronous,1.059,asynchronous,1.034
# IGVH mutations in chronic lymphocytic leukemia,synchronous,0.951,asynchronous,0.965
# IL-1 Signaling,synchronous,0.926,asynchronous,0.961
# IL-6 Signalling,synchronous,0.912,asynchronous,0.92
# Influenza A Virus Replication Cycle,synchronous,0.888,asynchronous,0.916
# Iron acquisition and oxidative stress response in aspergillus fumigatus,synchronous,1.026,asynchronous,1.039
# Lac Operon,synchronous,0.995,asynchronous,1.0
# Lymphoid and myeloid cell specification and transdifferentiation,synchronous,1.041,asynchronous,1.071
# Lymphopoiesis Regulatory Network,synchronous,0.942,asynchronous,0.963
# MAPK Cancer Cell Fate Network,synchronous,0.976,asynchronous,1.019
# Mammalian Cell Cycle,synchronous,0.853,asynchronous,0.868
# Mammalian Cell Cycle 2006,synchronous,1.011,asynchronous,1.087
# Metabolic Interactions in the Gut Microbiome,synchronous,1.008,asynchronous,0.986
# Neurotransmitter Signaling Pathway,synchronous,0.993,asynchronous,0.974
# Oxidative Stress Pathway,synchronous,0.979,asynchronous,1.006
# PC12 Cell Differentiation,synchronous,0.958,asynchronous,0.919
# Predicting Variabilities in Cardiac Gene,synchronous,1.006,asynchronous,1.014
# Pro-inflammatory Tumor Microenvironment in Acute Lymphoblastic Leukemia,synchronous,0.971,asynchronous,1.013
# Processing of Spz Network from the Drosophila Signaling Pathway,synchronous,0.952,asynchronous,0.963
# Regulation of the L-arabinose operon of Escherichia coli,synchronous,1.05,asynchronous,1.009
# SKBR3 Breast Cell Line Long-term ErbB Network,synchronous,0.958,asynchronous,0.94
# SKBR3 Breast Cell Line Short-term ErbB Network,synchronous,0.79,asynchronous,0.869
# Senescence Associated Secretory Phenotype,synchronous,0.962,asynchronous,1.003
# Septation Initiation Network,synchronous,1.062,asynchronous,1.066
# Signal Transduction in Fibroblasts,synchronous,1.093,asynchronous,1.133
# Signaling Pathway for Butanol Production in Clostridium beijerinckii NRRL B-598,synchronous,0.986,asynchronous,0.985
# Signaling in Macrophage Activation,synchronous,0.932,asynchronous,0.978
# Stomatal Opening Model,synchronous,1.163,asynchronous,1.146
# T Cell Receptor Signaling,synchronous,0.949,asynchronous,0.954
# T cell differentiation,synchronous,1.036,asynchronous,1.021
# T-Cell Signaling 2006,synchronous,0.979,asynchronous,0.971
# T-LGL Survival Network 2008,synchronous,0.978,asynchronous,0.894
# T-LGL Survival Network 2011,synchronous,0.894,asynchronous,0.924
# T-LGL Survival Network 2011 Reduced Network,synchronous,1.046,asynchronous,0.927
# TOL Regulatory Network,synchronous,0.935,asynchronous,0.968
# Toll Pathway of Drosophila Signaling Pathway,synchronous,0.992,asynchronous,1.007
# Treatment of Castration-Resistant Prostate Cancer,synchronous,0.988,asynchronous,0.995
# Trichostrongylus retortaeformis,synchronous,1.022,asynchronous,1.057
# Tumour Cell Invasion and Migration,synchronous,0.703,asynchronous,0.889
# VEGF Pathway of Drosophila Signaling Pathway,synchronous,0.964,asynchronous,0.962
# Wg Pathway of Drosophila Signalling Pathways,synchronous,0.973,asynchronous,1.002
# Yeast Apoptosis,synchronous,0.951,asynchronous,0.933

# %%
with open('./data/derrida_coefficients.csv','w') as f:
    for model_name in sorted(sync_models):
        f.write(f'{model_name},synchronous,{round(sync_derrida_coefficients[model_name],3)},')
        f.write(f'asynchronous,{round(async_derrida_coefficients[model_name],3)}\n')
